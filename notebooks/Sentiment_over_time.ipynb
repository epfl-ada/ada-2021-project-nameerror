# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from functions import *

DATA_DIR = '../data'

JS_DATA_DIR = '../js_data'

# %%
df = pd.read_json(f'{DATA_DIR}/quotebank_attr_2015-2020.json.bz2', compression='bz2')
preprocess_dataframe(df, handle_birth_dates=True)

# %%
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-10-05-010038  At Neath Food Festival with a vegetarian platt...
# 1  2015-11-28-006688  But if I had to choose my favourite recipe, it...
# 2  2015-11-10-015422  Children are learning about responsibility, te...
# 3  2015-01-16-054273  Once we have added all the vegetables and stoc...
# 4  2015-02-20-089622                            vegans in a steakhouse.
#
#           speaker                                               qids  \
# 0  Bethan Jenkins                                         [Q4897688]
# 1   Trish Deseine                                         [Q7843986]
# 2     David Price  [Q1176177, Q16063598, Q20804677, Q20973688, Q3...
# 3             NaN                                                 []
# 4    Jim Gaffigan                                         [Q2093638]
#
#                  date  numOccurrences  \
# 0 2015-10-05 05:00:00               1
# 1 2015-11-28 00:00:00               1
# 2 2015-11-10 19:30:41               1
# 3 2015-01-16 11:40:11               4
# 4 2015-02-20 00:05:44               1
#
#                                               probas  \
# 0         [[Bethan Jenkins, 0.8565], [None, 0.1435]]
# 1  [[Trish Deseine, 0.7664], [None, 0.1125], [Kei...
# 2            [[David Price, 0.7849], [None, 0.2151]]
# 3      [[None, 0.6778], [Catherine O'Neill, 0.3222]]
# 4           [[Jim Gaffigan, 0.7894], [None, 0.2106]]
#
#                                                 urls phase speaker_qid  \
# 0  [http://www.southwales-eveningpost.co.uk/Town-...     E    Q4897688
# 1  [http://www.irishexaminer.com/lifestyle/featur...     E    Q7843986
# 2  [http://news.ifas.ufl.edu/2015/11/ufifas-bok-t...     E        None
# 3  [http://www.bromsgrovestandard.co.uk/2015/01/1...     E        None
# 4  [http://unfspinnaker.com/expect-jim-gaffigans-...     E    Q2093638
#
#    gender                 nationality date_of_birth ethnic_group  \
# 0    None                        None           NaT         None
# 1    None                        None           NaT         None
# 2    None                        None           NaT         None
# 3    None                        None           NaT         None
# 4  [male]  [United States of America]    1966-07-07         None
#
#                                           occupation party academic_degree  \
# 0                                               None  None            None
# 1                                               None  None            None
# 2                                               None  None            None
# 3                                               None  None            None
# 4  [screenwriter, film producer, television actor...  None            None
#
#                                              domains
# 0                     [southwales-eveningpost.co.uk]
# 1                                [irishexaminer.com]
# 2                                          [ufl.edu]
# 3  [bromsgrovestandard.co.uk, bromsgrovestandard....
# 4                                 [unfspinnaker.com]

# %%
df_sentiments = extend_with_sentiment_polarity_scores(df)

# %%
compound_per_month = group_by_date_col(df_sentiments, 'date', freq='MS')\
    .agg({'compound': ['mean', 'sem'] })\
    .reset_index()

fig, ax = plt.subplots(figsize=(10, 8))
show_mean_with_sem(ax, 
    compound_per_month['date'], 
    compound_per_month['compound']['mean'], 
    compound_per_month['compound']['sem'], 
    color='black')
ax.set(title='Mean sentiment of quotes over time calculated per month',
    xlabel='Date', ylabel='Sentiment (ranging from -1 for negative to 1 being positive and 0 neutral)')
plt.ylim([-1, 1])
plt.show()

# %%
export_as_json({
    'dates': list(map(str, list(compound_per_month['date']))),
    'mean': list(compound_per_month['compound']['mean']),
    'sem': list(compound_per_month['compound']['sem'])
}, f'{JS_DATA_DIR}/general-sentiment-over-time.json')

# %% [markdown]
# # Effect of attributes on sentiment
#
# We take a look how different value of attributes affect sentiment, starting with basic plots:

# %%
df_sentiments.head()
# Out:
#              quoteID                                          quotation  \
# 0  2015-10-05-010038  At Neath Food Festival with a vegetarian platt...
# 1  2015-11-28-006688  But if I had to choose my favourite recipe, it...
# 2  2015-11-10-015422  Children are learning about responsibility, te...
# 3  2015-01-16-054273  Once we have added all the vegetables and stoc...
# 4  2015-02-20-089622                            vegans in a steakhouse.
#
#           speaker                                               qids  \
# 0  Bethan Jenkins                                         [Q4897688]
# 1   Trish Deseine                                         [Q7843986]
# 2     David Price  [Q1176177, Q16063598, Q20804677, Q20973688, Q3...
# 3             NaN                                                 []
# 4    Jim Gaffigan                                         [Q2093638]
#
#                  date  numOccurrences  \
# 0 2015-10-05 05:00:00               1
# 1 2015-11-28 00:00:00               1
# 2 2015-11-10 19:30:41               1
# 3 2015-01-16 11:40:11               4
# 4 2015-02-20 00:05:44               1
#
#                                               probas  \
# 0         [[Bethan Jenkins, 0.8565], [None, 0.1435]]
# 1  [[Trish Deseine, 0.7664], [None, 0.1125], [Kei...
# 2            [[David Price, 0.7849], [None, 0.2151]]
# 3      [[None, 0.6778], [Catherine O'Neill, 0.3222]]
# 4           [[Jim Gaffigan, 0.7894], [None, 0.2106]]
#
#                                                 urls phase speaker_qid  ...  \
# 0  [http://www.southwales-eveningpost.co.uk/Town-...     E    Q4897688  ...
# 1  [http://www.irishexaminer.com/lifestyle/featur...     E    Q7843986  ...
# 2  [http://news.ifas.ufl.edu/2015/11/ufifas-bok-t...     E        None  ...
# 3  [http://www.bromsgrovestandard.co.uk/2015/01/1...     E        None  ...
# 4  [http://unfspinnaker.com/expect-jim-gaffigans-...     E    Q2093638  ...
#
#   date_of_birth ethnic_group  \
# 0           NaT         None
# 1           NaT         None
# 2           NaT         None
# 3           NaT         None
# 4    1966-07-07         None
#
#                                           occupation party academic_degree  \
# 0                                               None  None            None
# 1                                               None  None            None
# 2                                               None  None            None
# 3                                               None  None            None
# 4  [screenwriter, film producer, television actor...  None            None
#
#                                              domains    neg    neu    pos  \
# 0                     [southwales-eveningpost.co.uk]  0.000  0.630  0.370
# 1                                [irishexaminer.com]  0.000  1.000  0.000
# 2                                          [ufl.edu]  0.000  0.739  0.261
# 3  [bromsgrovestandard.co.uk, bromsgrovestandard....  0.056  0.706  0.238
# 4                                 [unfspinnaker.com]  0.000  1.000  0.000
#
#    compound
# 0    0.5707
# 1    0.0000
# 2    0.8020
# 3    0.8004
# 4    0.0000
#
# [5 rows x 22 columns]

# %%
import matplotlib.patches as mpatches

def show_attr_sentiment_evolution(df, attr_name, cutoff, top_k, freq, export_for_js=False):
    """Plots sentiment over time for attribute attr_name over time for values
    over the given frequency appearing at least cutoff times in the whole dataset
    """
    fig, ax = plt.subplots(figsize=(14, 10))
    colors = ['blue', 'red', 'green', 'black', 'brown', 'orange']
    handles = []
    exportation_obj = {
        'year': None,
        'values': []
    }
    for i, value in enumerate(get_top_entries(df_sentiments, attr_name, cutoff_count=cutoff, top_k=top_k)):
        val_df = df[get_multivalue_col_mask(df, attr_name, value)]

        attr_compound_evolution = group_by_date_col(val_df, 'date', freq=freq)\
            .agg({'compound': ['mean', 'sem'] })\
            .reset_index()
        color = colors[i % len(colors)]
        handles.append(mpatches.Patch(color=color, label=value))

        show_mean_with_sem(ax, 
            attr_compound_evolution['date'], 
            attr_compound_evolution['compound']['mean'], 
            attr_compound_evolution['compound']['sem'], 
            color=color,
            alpha=0.05)

        if exportation_obj['year'] is None:
            exportation_obj['year'] = list(attr_compound_evolution['date'].apply(lambda d: d.year))
        exportation_obj['values'].append({
            'value': value,
            'mean': list(attr_compound_evolution['compound']['mean']),
            'sem': list(attr_compound_evolution['compound']['sem'])
        })
    if export_for_js:
        export_as_json(exportation_obj, f'{JS_DATA_DIR}/{attr_name}-sentiment-correlation.json')
    ax.set(title=f'Mean sentiment of quotes over time calculated per month for attribute \'{attr_name}\'',
        xlabel='Date', ylabel='Sentiment (ranging from -1 for negative to 1 being positive and 0 neutral)')
    ax.legend(handles=handles, title=f'Attribute value')
    plt.ylim([-1, 1])
    plt.show()

# %%
cols_to_visualize_sentiment_evolution = ['gender', 'nationality',
       'ethnic_group', 'occupation', 'party',
       'academic_degree']
for attr_name in cols_to_visualize_sentiment_evolution:
    show_attr_sentiment_evolution(df_sentiments, attr_name=attr_name, cutoff=-1, top_k=5, freq='YS')

# %% [markdown]
# We save these values in JSON to be used in the datastory with argument `export_for_js`:

# %%
show_attr_sentiment_evolution(df_sentiments, 'gender', cutoff=-1, top_k=2, freq='YS', export_for_js=True)
show_attr_sentiment_evolution(df_sentiments, 'occupation', cutoff=-1, top_k=6, freq='YS', export_for_js=True)

# %% [markdown]
# ### Hypothesis testing of the differences
#
# We see an apparent differences between some values of certain attributes in the above plots so we're doing hypothesis testing to check statistical significance of these differences. It makes little sense doing hypothesis testing on distributions with small number of samples, which is in above plots usually characterized by a large confidence interval, so focus mainly on distributions with a large sample size:

# %%
def get_attr_comparator(sentiments_per_attr):
    """Factory that creates a function that compared means of different values of an 
    attribute on a given sentiment array
    """
    def f(attr_name, value1, value2):
        """Perform hypothesis testing of means of sentiment compounds of entries with 
        values value1 and value2 for attr_name
        """
        print('Testing hypothesis that means of sentiment compounds of values '\
              f'{value1} and {value2} for attribute {attr_name} are drawn from the same distribution:')
        perform_hypothesis_testing_of_means(
            sentiments_per_attr[attr_name][value1], sentiments_per_attr[attr_name][value2])
    return f

# %%
to_check_sentiment_cols = ['gender', 'nationality',
       'ethnic_group', 'occupation', 'party',
       'academic_degree']

attr_sentiments = {
    attr_name: {
        value: df_sentiments[get_multivalue_col_mask(df_sentiments, attr_name, value)]['compound']\
        for value in get_top_entries(df_sentiments, attr_name)
    }\
    for attr_name in to_check_sentiment_cols
}

# %%
compare_attr_values = get_attr_comparator(attr_sentiments)

# %% [markdown]
# We first compare how similar are sentiments of male and female speakers, and as we can see their sentiments are different with high statistical significance with females likely having more positive average sentiment from the plots above:

# %%
compare_attr_values('gender', 'male', 'female')
# Out:
# Testing hypothesis that means of sentiment compounds of values male and female for attribute gender are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 1.2358374156959785e-21
#  ----| Welch’s t-test p-value: 4.7302865062341435e-22
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]

# %% [markdown]
# We do the same for actors and politians and see their difference is also statistically significant with actors likely having more positive average sentiment from the plots above:

# %%
compare_attr_values('occupation', 'actor', 'politician')
# Out:
# Testing hypothesis that means of sentiment compounds of values actor and politician for attribute occupation are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 7.578712064130518e-09
#  ----| Welch’s t-test p-value: 5.397353612667226e-09
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]

# %% [markdown]
# We repeat the same for nationality and compare India which on first sight have much lower average sentiment compound than other countries and hypothesis testing confirms that a difference in fact likely exists:

# %%
for country2 in ['United States of America', 'United Kingdom', 'Australia', 'Canada']:
    compare_attr_values('nationality', 'India', 'United States of America')
# Out:
# Testing hypothesis that means of sentiment compounds of values India and United States of America for attribute nationality are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 1.3297094185288136e-09
#  ----| Welch’s t-test p-value: 9.674985677112454e-09
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]
# Testing hypothesis that means of sentiment compounds of values India and United States of America for attribute nationality are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 1.3297094185288136e-09
#  ----| Welch’s t-test p-value: 9.674985677112454e-09
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]
# Testing hypothesis that means of sentiment compounds of values India and United States of America for attribute nationality are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 1.3297094185288136e-09
#  ----| Welch’s t-test p-value: 9.674985677112454e-09
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]
# Testing hypothesis that means of sentiment compounds of values India and United States of America for attribute nationality are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 1.3297094185288136e-09
#  ----| Welch’s t-test p-value: 9.674985677112454e-09
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]

# %% [markdown]
# As a sanity check we compare Canada and UK with USA and see that in case of UK and USA p-value is higher which suggests the distribution are more likely to be same than in case of India, but still with small probability. In case of Canada and USA, we can't reject the null hypothesis so easy anymore!

# %%
compare_attr_values('nationality', 'United Kingdom', 'United States of America')
compare_attr_values('nationality', 'Canada', 'United States of America')
# Out:
# Testing hypothesis that means of sentiment compounds of values United Kingdom and United States of America for attribute nationality are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.003436957803287688
#  ----| Welch’s t-test p-value: 0.004308153974238263
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]
# Testing hypothesis that means of sentiment compounds of values Canada and United States of America for attribute nationality are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.06177940930966209
#  ----| Welch’s t-test p-value: 0.07189052743955478
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]

# %% [markdown]
# #### Changes of testing over time
#
# We now look for evolution of sentiment compound over time for a fixed value of a certain attribute.

# %%
def compare_over_years(df, attr_name, value, year1, year2):
    """Compare sentiment compound of entries with value in place of attr_name 
    in years year1 and year2
    """
    attr_val_df = df[get_multivalue_col_mask(df, attr_name, value)]
    attr_val_df = pd.concat([
        attr_val_df['date'].apply(lambda d: d.year).rename('date'),
        attr_val_df['compound']
    ], axis=1)
    
    distribution1 = attr_val_df[attr_val_df['date'] == year1]['compound']
    distribution2 = attr_val_df[attr_val_df['date'] == year2]['compound']
    print(f'Testing hypothesis that means of sentiment compounds of value {value} of {attr_name} '\
          f'in years {year1} and {year2} are drawn from the same distribution:')
    perform_hypothesis_testing_of_means(distribution1, distribution2)

# %% [markdown]
# In plots we can see that writers have a dip in 2017 and we test this and confirm the difference between 2015 and 2017 as well as 2017 and 2020 is statistically significant in sentiment, while 2015 and 2020 are far more likely to be drawn from the same distribution under the null hypothesis:

# %%
compare_over_years(df_sentiments, 'occupation', 'writer', 2015, 2017)
compare_over_years(df_sentiments, 'occupation', 'writer', 2017, 2020)
compare_over_years(df_sentiments, 'occupation', 'writer', 2015, 2020)
# Out:
# Testing hypothesis that means of sentiment compounds of value writer of occupation in years 2015 and 2017 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.008160463426982538
#  ----| Welch’s t-test p-value: 0.006684922922697378
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]
# Testing hypothesis that means of sentiment compounds of value writer of occupation in years 2017 and 2020 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.0070657966046388035
#  ----| Welch’s t-test p-value: 0.006232086368771236
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]
# Testing hypothesis that means of sentiment compounds of value writer of occupation in years 2015 and 2020 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.9634892652243279
#  ----| Welch’s t-test p-value: 0.9634518952812231
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]

# %% [markdown]
# In the plots it may seem that politician's sentiment may be slowly dropping, but hypothesis testing show that we can't high confidence confirm that this drop is the case on year er year basis, but let's compare ends of the interval:

# %%
for year in range(2015, 2020):
    compare_over_years(df_sentiments, 'occupation', 'politician', year, year + 1)
# Out:
# Testing hypothesis that means of sentiment compounds of value politician of occupation in years 2015 and 2016 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.7426744025465919
#  ----| Welch’s t-test p-value: 0.7436119424030698
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]
# Testing hypothesis that means of sentiment compounds of value politician of occupation in years 2016 and 2017 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.0792408123869532
#  ----| Welch’s t-test p-value: 0.07633026502005223
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]
# Testing hypothesis that means of sentiment compounds of value politician of occupation in years 2017 and 2018 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.4047667644551889
#  ----| Welch’s t-test p-value: 0.40419636199716324
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]
# Testing hypothesis that means of sentiment compounds of value politician of occupation in years 2018 and 2019 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.9252173738863165
#  ----| Welch’s t-test p-value: 0.9256777623278339
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]
# Testing hypothesis that means of sentiment compounds of value politician of occupation in years 2019 and 2020 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.06520939001537708
#  ----| Welch’s t-test p-value: 0.06620129809676137
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNDECIDABLE]

# %% [markdown]
# Even when looking at opposing ends of the interval we can confidently confirm that this drop is statistically significant:

# %%
compare_over_years(df_sentiments, 'occupation', 'politician', 2015, 2020)
# Out:
# Testing hypothesis that means of sentiment compounds of value politician of occupation in years 2015 and 2020 are drawn from the same distribution:
#  ----| Standard independent 2 sample test p-value: 0.014574176241330401
#  ----| Welch’s t-test p-value: 0.014744408868722593
#  ====> Conclusion: The equality of the expected values of the given distributions is [UNLIKELY]

# %% [markdown]
# ## Empathy analysis
#
# Next we look at evolution of different emotions in the quotations over past few years:

# %%
from empath import Empath
lexicon = Empath()

# %%
lexicon.cats.keys()
# Out:
# dict_keys(['help', 'office', 'dance', 'money', 'wedding', 'domestic_work', 'sleep', 'medical_emergency', 'cold', 'hate', 'cheerfulness', 'aggression', 'occupation', 'envy', 'anticipation', 'family', 'vacation', 'crime', 'attractive', 'masculine', 'prison', 'health', 'pride', 'dispute', 'nervousness', 'government', 'weakness', 'horror', 'swearing_terms', 'leisure', 'suffering', 'royalty', 'wealthy', 'tourism', 'furniture', 'school', 'magic', 'beach', 'journalism', 'morning', 'banking', 'social_media', 'exercise', 'night', 'kill', 'blue_collar_job', 'art', 'ridicule', 'play', 'computer', 'college', 'optimism', 'stealing', 'real_estate', 'home', 'divine', 'sexual', 'fear', 'irritability', 'superhero', 'business', 'driving', 'pet', 'childish', 'cooking', 'exasperation', 'religion', 'hipster', 'internet', 'surprise', 'reading', 'worship', 'leader', 'independence', 'movement', 'body', 'noise', 'eating', 'medieval', 'zest', 'confusion', 'water', 'sports', 'death', 'healing', 'legend', 'heroic', 'celebration', 'restaurant', 'violence', 'programming', 'dominant_heirarchical', 'military', 'neglect', 'swimming', 'exotic', 'love', 'hiking', 'communication', 'hearing', 'order', 'sympathy', 'hygiene', 'weather', 'anonymity', 'trust', 'ancient', 'deception', 'fabric', 'air_travel', 'fight', 'dominant_personality', 'music', 'vehicle', 'politeness', 'toy', 'farming', 'meeting', 'war', 'speaking', 'listen', 'urban', 'shopping', 'disgust', 'fire', 'tool', 'phone', 'gain', 'sound', 'injury', 'sailing', 'rage', 'science', 'work', 'appearance', 'valuable', 'warmth', 'youth', 'sadness', 'fun', 'emotional', 'joy', 'affection', 'traveling', 'fashion', 'ugliness', 'lust', 'shame', 'torment', 'economics', 'anger', 'politics', 'ship', 'clothing', 'car', 'strength', 'technology', 'breaking', 'shape_and_size', 'power', 'white_collar_job', 'animal', 'party', 'terrorism', 'smell', 'disappointment', 'poor', 'plant', 'pain', 'beauty', 'timidity', 'philosophy', 'negotiate', 'negative_emotion', 'cleaning', 'messaging', 'competing', 'law', 'friends', 'payment', 'achievement', 'alcohol', 'liquid', 'feminine', 'weapon', 'children', 'monster', 'ocean', 'giving', 'contentment', 'writing', 'rural', 'positive_emotion', 'musical', 'healthy_food', 'festive_food'])

# %%
def empath_analysis_per_year(df, categories_to_analyze, lexicon):
    """Returns dataframe of percentage of each of specified emotional categories 
    on per-year basis between 2015 and 2020
    """
    years = list(range(2015, 2021))
    result_per_year = []
    for year in years:
        mask = df['date'].apply(lambda d: d.year == year)
        target_quotation_list = list(df[mask]['quotation'])
        result_per_year.append({
            'year': year,
            **lexicon.analyze(target_quotation_list, categories_to_analyze, normalize=True)
        })
    return pd.DataFrame(result_per_year).set_index('year')

# %%
categories = ['plant', 'animal', 'healthy_food', 'pet', 'kill', 'aggression', 'social_media', 'suffering', 'water', 'fear', 'death', 'children']
data = empath_analysis_per_year(df, categories, lexicon)
data
# Out:
#          plant    animal  healthy_food       pet      kill  aggression  \
# year
# 2015  0.009170  0.002890      0.009143  0.000885  0.000852    0.000897
# 2016  0.009566  0.002858      0.008373  0.001061  0.000757    0.000770
# 2017  0.009184  0.002823      0.008099  0.001038  0.000800    0.000852
# 2018  0.008439  0.002824      0.007116  0.000976  0.000879    0.000953
# 2019  0.007946  0.002821      0.006353  0.001202  0.000700    0.000946
# 2020  0.007109  0.002733      0.007169  0.001109  0.000786    0.000904
#
#       social_media  suffering     water      fear     death  children
# year
# 2015      0.000891   0.001260  0.002446  0.000355  0.001439  0.003465
# 2016      0.001044   0.001202  0.002191  0.000560  0.001151  0.003474
# 2017      0.001042   0.001406  0.002199  0.000477  0.001472  0.003693
# 2018      0.001142   0.001224  0.002236  0.000565  0.001399  0.003420
# 2019      0.001170   0.001319  0.001988  0.000583  0.001242  0.003110
# 2020      0.001294   0.001162  0.001835  0.000541  0.001274  0.002568

# %%
def display_category_evolution(data, categories, ax_set_dict=None, top_k= 0):
    x_col = 'year'
    if top_k > 0:
        top_k_y_cols = data[categories].max(axis=0).sort_values(ascending=False)[:top_k].index
    else:
        top_k_y_cols = categories

    fig, ax = plt.subplots(figsize=(14, 10))
    for y_col in top_k_y_cols:
        sns.lineplot(data=data, x=x_col, y=y_col, ax=ax)
    if ax_set_dict is not None:
        ax.set(**ax_set_dict)
    ax.legend(top_k_y_cols)
    plt.show()

# %% [markdown]
# First let's look at evolution of each emotion with their overall frequency taken into account:

# %%
display_category_evolution(data, categories, ax_set_dict={
    'title': 'Presence of different emotions and topics in quotes over time on per-year basis',
    'xlabel': 'Time', 
    'ylabel': 'Presence based on emotion related terms in percentage' 
}, top_k=10)

# %% [markdown]
# Now, let's normalize each column to look at evolution of each emotion over time:

# %%
k_to_select = 4
cols_to_select = data[categories].max(axis=0).sort_values(ascending=False)[:k_to_select].index

normalized_per_col_data = data / data.max(axis=0)
display_category_evolution(normalized_per_col_data, cols_to_select, ax_set_dict={
    'title': 'Evolution of emotions over time on per-year basis',
    'xlabel': 'Time', 
    'ylabel': 'Presence of emotions compared to their peak presence' 
})

# %% [markdown]
# Most present emotions ordered by their presence in 2020:

# %%
data[data.index == 2020].iloc[0].sort_values(ascending=False)
# Out:
# healthy_food    0.007169
# plant           0.007109
# animal          0.002733
# children        0.002568
# water           0.001835
# social_media    0.001294
# death           0.001274
# suffering       0.001162
# pet             0.001109
# aggression      0.000904
# kill            0.000786
# fear            0.000541
# Name: 2020, dtype: float64

# %% [markdown]
# Most present emotions ordered by their peak presence in any year between 2015 and 2020:

# %%
data.max(axis=0).sort_values(ascending=False)
# Out:
# plant           0.009566
# healthy_food    0.009143
# children        0.003693
# animal          0.002890
# water           0.002446
# death           0.001472
# suffering       0.001406
# social_media    0.001294
# pet             0.001202
# aggression      0.000953
# kill            0.000879
# fear            0.000583
# dtype: float64

# %%
export_as_json({
    'year': list(data.index),
    'data': [
        {
            'emotion': col_name,
            'values': list(data[col_name])
        }\
        for col_name in data.columns
    ],
    'normalized_data': [
         {
            'emotion': col_name,
            'values': list(normalized_per_col_data[col_name])
        }\
        for col_name in normalized_per_col_data.columns
    ]
}, '../js_data/empath_analysis.json')

# %% [markdown]
# ## Wordcloud

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
nlp.remove_pipe('parser')
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f23d9c131c0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f23d9c13820>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f23cf5d0480>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f23cf658580>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f23d9e2d890>)]

# %%
processed_quotes = [
    nlp(quote)\
    for quote in list(df['quotation'])
]

# %%
from collections import Counter

# %%
def is_in_any(list_of_strings, text):
    return any(map(lambda s: text in s, list_of_strings))

def get_useful_tokens(processed_quote):
    entities = [ent.lemma_ for ent in processed_quote.ents]
    result = []
    for token in processed_quote:
        if token.is_stop != True and token.is_punct != True and not is_in_any(entities, token.lemma_):
            result.append(token.lemma_)
    result.extend(entities)
    return result

# %%
all_words = []

for processed_quote in processed_quotes:
    all_words.extend(get_useful_tokens(processed_quote))

# %%
from wordcloud import WordCloud

WC_BACKGROUND = 'white'
MAX_WORDS = 1000
WC_WIDTH, WC_HEIGHT = 1000, 1000
word_cloud = WordCloud(
    background_color=WC_BACKGROUND, 
    max_words=MAX_WORDS, 
    width=WC_WIDTH, 
    height=WC_HEIGHT)

# Calculate wordcloud
wc = word_cloud.generate_from_frequencies(Counter(all_words))

# Plot wordcloud
fig, ax = plt.subplots(figsize=(14, 14))
ax.imshow(wc)
ax.axis('off')
ax.set(title='Cloud of most frequent words in the quotations')
plt.show()

# %% [markdown]
# We further export these word sorted descendingly by frequency to be able to use them in javascript:

# %%
words_to_keep = 2000
words_sorted_by_frequency = [
    entry[0]\
    for entry in Counter(all_words).most_common(words_to_keep)
]

words_sorted_by_frequency
export_as_json(words_sorted_by_frequency, f'{JS_DATA_DIR}/wordcloud-words-top-{words_to_keep}.json')

# %% [markdown]
# ## Regression analysis
#
# Date attribute doesn't have normal distribution nor outliers so it would make sense to use normalization:

# %%
sns.histplot(data=df_sentiments, x='date')
# Out:
# <AxesSubplot:xlabel='date', ylabel='Count'>

# %% [markdown]
# Date of birth attribute has normal distribution and outliers so it would make sense to use standardization:

# %%
sns.histplot(data=df_sentiments, x='date_of_birth')
# Out:
# <AxesSubplot:xlabel='date_of_birth', ylabel='Count'>

# %%
import statsmodels.api as sm

# %%
multival_cols = ['gender', 'nationality', 'ethnic_group', 'occupation', 'party', 'academic_degree']
cutoff = 200

release_time = normalize(df_sentiments['date'])

dfs_to_merge = []
for col in multival_cols:
    multihot_df = multi_hot(df, col, cutoff)
    if multihot_df is not None:
        dfs_to_merge.append(multihot_df)
        multihot_over_time = multihot_df.multiply(release_time, axis='rows')
        multihot_over_time.columns = list(map(lambda name: f'{name}_over_time', multihot_over_time.columns))
        dfs_to_merge.append(multihot_over_time)
        
dfs_to_merge.append(release_time)
# dfs_to_merge.append(standardize(df_sentiments['date_of_birth']).fillna(0))
        
regression_in = sm.add_constant(pd.concat(dfs_to_merge, axis=1))
regression_out = df_sentiments['compound']
# Out:
# /home/milos/Anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model = sm.OLS(regression_out, regression_in).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               compound   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     4.702
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):           3.60e-41
# Time:                        18:49:05   Log-Likelihood:                -43077.
# No. Observations:               66584   AIC:                         8.632e+04
# Df Residuals:                   66500   BIC:                         8.709e+04
# Df Model:                          83
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                              0.2443      0.004     54.832      0.000       0.236       0.253
# gender_male                                        0.0081      0.027      0.297      0.766      -0.045       0.061
# gender_female                                      0.0378      0.032      1.196      0.232      -0.024       0.100
# gender_male_over_time                             -0.0419      0.038     -1.108      0.268      -0.116       0.032
# gender_female_over_time                            0.0204      0.044      0.459      0.646      -0.067       0.107
# nationality_United States of America              -0.0225      0.034     -0.668      0.504      -0.088       0.043
# nationality_United Kingdom                        -0.0132      0.041     -0.319      0.750      -0.094       0.068
# nationality_India                                 -0.0487      0.044     -1.117      0.264      -0.134       0.037
# nationality_Australia                             -0.0083      0.050     -0.168      0.867      -0.106       0.089
# nationality_Canada                                 0.0242      0.062      0.388      0.698      -0.098       0.146
# nationality_United States of America_over_time     0.0352      0.048      0.732      0.464      -0.059       0.129
# nationality_United Kingdom_over_time               0.0126      0.058      0.218      0.827      -0.101       0.126
# nationality_India_over_time                       -0.0227      0.061     -0.373      0.709      -0.142       0.097
# nationality_Australia_over_time                   -0.0090      0.070     -0.127      0.899      -0.147       0.129
# nationality_Canada_over_time                       0.0438      0.089      0.491      0.623      -0.131       0.219
# ethnic_group_African Americans                     0.0853      0.059      1.446      0.148      -0.030       0.201
# ethnic_group_African Americans_over_time          -0.1272      0.091     -1.398      0.162      -0.306       0.051
# occupation_politician                             -0.0463      0.036     -1.294      0.196      -0.117       0.024
# occupation_actor                                  -0.0120      0.045     -0.269      0.788      -0.100       0.076
# occupation_film actor                              0.1038      0.061      1.689      0.091      -0.017       0.224
# occupation_writer                                 -0.0583      0.037     -1.586      0.113      -0.130       0.014
# occupation_television actor                       -0.0760      0.068     -1.125      0.260      -0.208       0.056
# occupation_model                                   0.0671      0.052      1.299      0.194      -0.034       0.168
# occupation_singer                                  0.0451      0.062      0.724      0.469      -0.077       0.167
# occupation_television presenter                   -0.0773      0.052     -1.475      0.140      -0.180       0.025
# occupation_businessperson                         -0.1397      0.054     -2.588      0.010      -0.246      -0.034
# occupation_film producer                          -0.0729      0.057     -1.286      0.199      -0.184       0.038
# occupation_journalist                             -0.0533      0.047     -1.127      0.260      -0.146       0.039
# occupation_voice actor                             0.0404      0.066      0.611      0.541      -0.089       0.170
# occupation_television producer                    -0.0493      0.067     -0.732      0.464      -0.181       0.083
# occupation_lawyer                                 -0.0461      0.057     -0.808      0.419      -0.158       0.066
# occupation_chef                                    0.2355      0.047      5.046      0.000       0.144       0.327
# occupation_screenwriter                           -0.0074      0.069     -0.108      0.914      -0.142       0.128
# occupation_researcher                              0.1471      0.067      2.194      0.028       0.016       0.279
# occupation_singer-songwriter                       0.0329      0.086      0.380      0.704      -0.137       0.202
# occupation_entrepreneur                            0.0577      0.072      0.798      0.425      -0.084       0.200
# occupation_animal rights advocate                 -0.0763      0.075     -1.022      0.307      -0.223       0.070
# occupation_musician                               -0.0328      0.091     -0.360      0.719      -0.211       0.146
# occupation_stage actor                             0.1359      0.086      1.578      0.114      -0.033       0.305
# occupation_songwriter                             -0.1167      0.086     -1.351      0.177      -0.286       0.053
# occupation_fashion designer                       -0.1437      0.080     -1.801      0.072      -0.300       0.013
# occupation_university teacher                     -0.0370      0.067     -0.549      0.583      -0.169       0.095
# occupation_autobiographer                         -0.0343      0.080     -0.430      0.667      -0.190       0.122
# occupation_film director                          -0.1083      0.081     -1.337      0.181      -0.267       0.050
# occupation_physician                              -0.1347      0.092     -1.458      0.145      -0.316       0.046
# occupation_composer                                0.0006      0.090      0.006      0.995      -0.176       0.177
# occupation_environmentalist                        0.0142      0.092      0.155      0.877      -0.166       0.194
# occupation_politician_over_time                   -0.0051      0.050     -0.102      0.919      -0.103       0.093
# occupation_actor_over_time                         0.0192      0.065      0.297      0.767      -0.107       0.146
# occupation_film actor_over_time                   -0.0820      0.088     -0.935      0.350      -0.254       0.090
# occupation_writer_over_time                        0.1220      0.054      2.238      0.025       0.015       0.229
# occupation_television actor_over_time              0.0975      0.095      1.027      0.304      -0.089       0.283
# occupation_model_over_time                        -0.0029      0.074     -0.039      0.969      -0.148       0.142
# occupation_singer_over_time                       -0.0659      0.087     -0.753      0.452      -0.237       0.106
# occupation_television presenter_over_time          0.0351      0.075      0.468      0.640      -0.112       0.182
# occupation_businessperson_over_time                0.2311      0.075      3.077      0.002       0.084       0.378
# occupation_film producer_over_time                 0.0692      0.083      0.830      0.406      -0.094       0.233
# occupation_journalist_over_time                   -0.1002      0.070     -1.430      0.153      -0.238       0.037
# occupation_voice actor_over_time                   0.0017      0.097      0.017      0.986      -0.189       0.192
# occupation_television producer_over_time          -0.0015      0.097     -0.015      0.988      -0.192       0.189
# occupation_lawyer_over_time                        0.0865      0.085      1.022      0.307      -0.079       0.252
# occupation_chef_over_time                         -0.1980      0.073     -2.729      0.006      -0.340      -0.056
# occupation_screenwriter_over_time                 -0.0261      0.103     -0.253      0.800      -0.228       0.176
# occupation_researcher_over_time                   -0.2249      0.087     -2.594      0.009      -0.395      -0.055
# occupation_singer-songwriter_over_time            -0.0050      0.119     -0.042      0.967      -0.238       0.228
# occupation_entrepreneur_over_time                 -0.0852      0.104     -0.816      0.415      -0.290       0.120
# occupation_animal rights advocate_over_time        0.2807      0.112      2.507      0.012       0.061       0.500
# occupation_musician_over_time                      0.0880      0.125      0.706      0.480      -0.156       0.332
# occupation_stage actor_over_time                  -0.1753      0.127     -1.380      0.168      -0.424       0.074
# occupation_songwriter_over_time                    0.0668      0.124      0.540      0.589      -0.175       0.309
# occupation_fashion designer_over_time             -0.0044      0.118     -0.037      0.970      -0.235       0.227
# occupation_university teacher_over_time            0.1425      0.104      1.370      0.171      -0.061       0.346
# occupation_autobiographer_over_time               -0.0708      0.120     -0.588      0.557      -0.307       0.165
# occupation_film director_over_time                 0.0785      0.121      0.649      0.516      -0.158       0.315
# occupation_physician_over_time                     0.1752      0.133      1.321      0.187      -0.085       0.435
# occupation_composer_over_time                     -0.0591      0.120     -0.491      0.623      -0.295       0.177
# occupation_environmentalist_over_time             -0.0356      0.128     -0.279      0.780      -0.286       0.215
# party_Democratic Party                             0.1678      0.052      3.246      0.001       0.066       0.269
# party_Republican Party                             0.0238      0.062      0.385      0.701      -0.097       0.145
# party_Bharatiya Janata Party                       0.1571      0.087      1.812      0.070      -0.013       0.327
# party_Democratic Party_over_time                  -0.2391      0.077     -3.124      0.002      -0.389      -0.089
# party_Republican Party_over_time                   0.0556      0.094      0.594      0.552      -0.128       0.239
# party_Bharatiya Janata Party_over_time            -0.1925      0.125     -1.546      0.122      -0.437       0.052
# date                                               0.0125      0.007      1.723      0.085      -0.002       0.027
# ==============================================================================
# Omnibus:                     3415.249   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2406.938
# Skew:                          -0.360   Prob(JB):                         0.00
# Kurtosis:                       2.409   Cond. No.                         121.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Attributes for which can be said that likely affect the sentiment from statistical significance standpoint:

# %%
pvalues_of_model = model.pvalues
pvalue_mask = pvalues_of_model < 5e-2
significant_params = model.params[pvalue_mask].sort_values(ascending=False).reset_index()
significant_params.columns = ['param name', 'coefficient']
significant_params
# Out:
#                                      param name  coefficient
# 0   occupation_animal rights advocate_over_time     0.280686
# 1                                         const     0.244286
# 2                               occupation_chef     0.235526
# 3           occupation_businessperson_over_time     0.231112
# 4                        party_Democratic Party     0.167834
# 5                         occupation_researcher     0.147141
# 6                   occupation_writer_over_time     0.121967
# 7                     occupation_businessperson    -0.139746
# 8                     occupation_chef_over_time    -0.197956
# 9               occupation_researcher_over_time    -0.224925
# 10             party_Democratic Party_over_time    -0.239069

# %% [markdown]
# As we can see over time sentiments becomes more positive. Highest effect on positivity of sentiments has being chef, animal rights advocate or model. Being Canadian also positively affects the sentiment. Same applies to being a female or a film actor.
#
# On the opposite site we have that being Indian has negative effect on sentiment. Also occupations that have negative effect on sentiment are: politician, television presenter, songwritter, autobiographer, journalist and fashion designer in the given order by increasing negativity of sentiment.
#
# It is however important to note that the given linear regressor explains only a small portion of the variance in the data, so these results should be taken with a grain of salt.

# %%
export_as_json({
    'param name': list(significant_params['param name']),
    'coef': list(significant_params['coefficient'])
}, '../js_data/significant_params.json')
