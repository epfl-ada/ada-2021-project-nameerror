# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from flair.models import SequenceTagger, TextClassifier
from flair.data import Sentence
from flair.embeddings import WordEmbeddings
from flair.tokenization import SegtokSentenceSplitter

DATA_DIR = '../data'

# %%
df = pd.read_json(f'{DATA_DIR}/fine_filtered2020_attrs.json.bz2', compression='bz2')
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2020-02-13-100687  This diet focuses on lifelong changes to healt...
# 1  2020-02-07-007719  As an empowered female leader myself, I am thr...
# 2  2020-01-21-098307  We stack the freshly plucked fruits into three...
# 3  2020-02-12-011869  Burger Burger will use local produce as much a...
# 4  2020-01-07-042453  It's likely that as we're seeing drier conditi...
#
#     speaker         qids                date  numOccurrences  \
# 0      None           [] 2020-02-13 18:22:19               1
# 1      None           [] 2020-02-07 13:09:21               1
# 2  Sahi Ram  [Q19605026] 2020-01-21 12:49:00               1
# 3      None           [] 2020-02-12 18:56:09               1
# 4      None           [] 2020-01-07 23:40:00               2
#
#                                        probas  \
# 0        [[None, 0.8001], [Dr. Sebi, 0.1999]]
# 1       [[None, 0.9507], [Maye Musk, 0.0493]]
# 2        [[Sahi Ram, 0.9035], [None, 0.0965]]
# 3        [[None, 0.9078], [El Chapo, 0.0922]]
# 4  [[None, 0.9688], [Scott Morrison, 0.0312]]
#
#                                                 urls phase speaker_qid  \
# 0  [https://parade.com/995529/christinperry/dr-se...     E        None
# 1  [https://www.perishablenews.com/produce/celebr...     E        None
# 2  [http://freshplaza.com/article/9181949/the-tin...     E   Q19605026
# 3  [https://www.belfastlive.co.uk/whats-on/food-d...     E        None
# 4  [http://msn.com/en-au/news/australia/kookaburr...     E        None
#
#    gender nationality            date_of_birth ethnic_group    occupation  \
# 0    None        None                     None         None          None
# 1    None        None                     None         None          None
# 2  [male]     [India]  [+1959-10-10T00:00:00Z]         None  [politician]
# 3    None        None                     None         None          None
# 4    None        None                     None         None          None
#
#                party academic_degree               domains
# 0               None            None          [parade.com]
# 1               None            None  [perishablenews.com]
# 2  [Aam Aadmi Party]            None      [freshplaza.com]
# 3               None            None   [belfastlive.co.uk]
# 4               None            None    [msn.com, msn.com]

# %% [markdown]
# # Tagging
#
# Here we experiment tagging on our dataset.

# %%
# Load NER
tagger = SequenceTagger.load('ner')
splitter = SegtokSentenceSplitter()
# Out:
# 2021-11-12 05:28:04,408 --------------------------------------------------------------------------------
# 2021-11-12 05:28:04,409 The model key 'ner' now maps to 'https://huggingface.co/flair/ner-english' on the HuggingFace ModelHub
# 2021-11-12 05:28:04,409  - The most current version of the model is automatically downloaded from there.
# 2021-11-12 05:28:04,409  - (you can alternatively manually download the original model at https://nlp.informatik.hu-berlin.de/resources/models/ner/en-ner-conll03-v0.4.pt)
# 2021-11-12 05:28:04,410 --------------------------------------------------------------------------------
# 2021-11-12 05:28:04,956 loading file /home/romain/.flair/models/ner-english/4f4cdab26f24cb98b732b389e6cebc646c36f54cfd6e0b7d3b90b25656e4262f.8baa8ae8795f4df80b28e7f7b61d788ecbb057d1dc85aacb316f1bd02837a4a4

# %%
full_text = '\n'.join(df['quotation'])
sentences = splitter.split(full_text)
tagger.predict(sentences)

# %%
spans = [el for sublist in list(map(lambda s: s.get_spans('ner'), sentences)) for el in sublist]
spans_df = pd.DataFrame([{
    'text': s.text,
    'tag': s.tag,
    'score': s.score
} for s in spans])
spans_df.head()
# Out:
#                text  tag     score
# 0     Burger Burger  ORG  0.981547
# 1  KVD Vegan Beauty  ORG  0.499235
# 2               Kat  PER  0.572307
# 3          Auckland  LOC  0.999819
# 4          Auckland  LOC  0.996379

# %% [markdown]
# ## Most cited organizations
#
# In the following cells, we experiment tagging and what we can learn about the cited organizations in our dataset.

# %%
org_spans = spans_df[spans_df['tag'] == 'ORG']

print(f"Most cited organizations (total = {len(org_spans)}):")
org_spans['text'].value_counts()[:15]
# Out:
# Most cited organizations (total = 610):
# HFPA                       10
# USDA                       10
# Beyond Meat                 8
# PETA India                  8
# Hollywood Foreign Press     8
# KENDO                       7
# KFC                         7
# BJP                         7
# Hälsa                       5
# KVD Vegan Beauty            5
# APMC                        4
# USMCA                       4
# MPC                         4
# CBD                         4
# PETA                        4
# Name: text, dtype: int64

# %% [markdown]
# These results are quite promising. We can expect to learn much more from it with the complete dataset (previous years) during the next milestone.
#
# Also, maybe it can be interesting to also tag the context around the quotations, because sometimes speakers talk about them while they are given around the quotation. The usage of acronyms can also alter the result. That's why it can be interesting to solve this problem using for example wikidata, which contains the acronyms and alias of organizations.

# %% [markdown]
# ## Most cited locations
#
# In the following cells, we experiment tagging and what we can learn about the cited locations in our dataset.

# %%
loc_spans = spans_df[spans_df['tag'] == 'LOC']

print(f"Most cited locations (total = {len(loc_spans)}):")
loc_spans['text'].value_counts()[:15]
# Out:
# Most cited locations (total = 888):
# India            30
# UK               26
# Australia        20
# U.S.             17
# China            14
# US               12
# Delhi            12
# Vermont           9
# Canada            8
# Goa               8
# Florida           8
# Europe            7
# Kolkata           7
# Topsia            7
# United States     7
# Name: text, dtype: int64

# %% [markdown]
# Same processing as before could be done here. Also, we sometimes have regions mentioned rather than country: we could use wikidata to map then to their countries for example, if we want to do a country analysis.

# %% [markdown]
# ## Most cited persons
#
# In the following cells, we experiment tagging and what we can learn about the cited persons in our dataset.

# %%
per_spans = spans_df[spans_df['tag'] == 'PER']

print(f"Most cited persons (total = {len(per_spans)}):")
per_spans['text'].value_counts()[:10]
# Out:
# Most cited persons (total = 551):
# Trump              13
# Joaquin Phoenix    12
# God                10
# Alex                8
# Joaquin             8
# Jon Richardson      8
# Greggs              6
# Thor                5
# Donald Trump        4
# Alzheimer           4
# Name: text, dtype: int64

# %% [markdown]
# Same comments as before.

# %% [markdown]
# ## Events tagging
#
# We experiment events tagging.

# %%
# Load NER Ontonotes
ontonotes_tagger = SequenceTagger.load('ner-ontonotes')
# Out:
# 2021-11-12 05:28:48,573 --------------------------------------------------------------------------------
# 2021-11-12 05:28:48,574 The model key 'ner-ontonotes' now maps to 'https://huggingface.co/flair/ner-english-ontonotes' on the HuggingFace ModelHub
# 2021-11-12 05:28:48,574  - The most current version of the model is automatically downloaded from there.
# 2021-11-12 05:28:48,575  - (you can alternatively manually download the original model at https://nlp.informatik.hu-berlin.de/resources/models/ner-ontonotes/en-ner-ontonotes-v0.4.pt)
# 2021-11-12 05:28:48,575 --------------------------------------------------------------------------------
# 2021-11-12 05:28:49,080 loading file /home/romain/.flair/models/ner-english-ontonotes/f46dcd14689a594a7dd2a8c9c001a34fd55b02fded2528410913c7e88dbe43d4.1207747bf5ae24291205b6f3e7417c8bedd5c32cacfb5a439f3eff38afda66f7

# %%
full_text = '\n'.join(df['quotation'])
sentences = splitter.split(full_text)
ontonotes_tagger.predict(sentences)

# %%
spans = [el for sublist in list(map(lambda s: s.get_spans('ner'), sentences)) for el in sublist]
spans_df = pd.DataFrame([{
    'text': s.text,
    'tag': s.tag,
    'score': s.score
} for s in spans])
spans_df.head()
# Out:
#                text       tag     score
# 0              Musk    PERSON  0.951681
# 1  every single day      DATE  0.914750
# 2             three  CARDINAL  0.999228
# 3               One  CARDINAL  0.998950
# 4             third   ORDINAL  0.999984

# %%
event_spans = spans_df[spans_df['tag'] == 'EVENT']

print(f"Most cited events (total = {len(event_spans)}):")
event_spans['text'].value_counts()[:10]
# Out:
# Most cited events (total = 38):
# Veganuary                                  2
# Olympic                                    2
# the Plant Based World Conference & Expo    2
# Australian Open                            2
# Annual Golden Globe Awards                 2
# New Year                                   2
# the UAE Innovation Month                   2
# the Adelaide Cup                           1
# Paralympic                                 1
# Valentine 's Day                           1
# Name: text, dtype: int64

# %% [markdown]
# The result is ok-tier. But we think that adding context could improve and help us to link events with our analysis.

# %% [markdown]
# ## Most cited products
#
# We experiment events tagging.

# %%
product_spans = spans_df[spans_df['tag'] == 'PRODUCT']

print(f"Most cited products (total = {len(product_spans)}):")
product_spans['text'].value_counts()[:10]
# Out:
# Most cited products (total = 62):
# the Beyond Burger                          3
# Covid-19                                   3
# Big Mac                                    2
# Sewa                                       2
# Marmite                                    2
# Beyond Meat                                2
# Impossible Foods'                          1
# Fanta                                      1
# Vegan Jack Wings                           1
# Biolage HydraSource Deep Treatment Pack    1
# Name: text, dtype: int64

# %% [markdown]
# # Word embedding

# %%
glove_embedding = WordEmbeddings('glove')

# %%
sentence = Sentence(df.loc[0].quotation)
glove_embedding.embed(sentence)

for token in sentence:
    print(token)
    print(token.embedding)
# Out:
# Token: 1 This
# tensor([-0.5706,  0.4418,  0.7010, -0.4171, -0.3406,  0.0234, -0.0715,  0.4818,
#         -0.0131,  0.1683, -0.1339,  0.0406,  0.1583, -0.4434, -0.0194, -0.0097,
#         -0.0463,  0.0932, -0.2733,  0.2285,  0.3309, -0.3647,  0.0787,  0.3585,
#          0.4476, -0.2299,  0.1808, -0.6265,  0.0539, -0.2915, -0.4256,  0.6290,
#          0.1439, -0.0460, -0.2101,  0.4888, -0.0577,  0.3743, -0.0301, -0.3449,
#         -0.2970,  0.1509,  0.2825, -0.1658,  0.0761, -0.0930,  0.7936, -0.6049,
#         -0.1887, -1.0173,  0.3196, -0.1634,  0.5418,  1.1725, -0.4787, -3.3842,
#         -0.0813, -0.3528,  1.8372,  0.4452, -0.5267,  0.9979, -0.3218,  0.0335,
#          1.1783, -0.0729,  0.3974,  0.2617,  0.3311, -0.3563, -0.1656, -0.4438,
#         -0.1418, -0.3798,  0.2899, -0.0291, -0.3517, -0.2769, -1.3440,  0.1955,
#          0.1689,  0.0402, -0.8021,  0.2337, -1.3837, -0.0231,  0.0854, -0.7405,
#         -0.0739, -0.5884, -0.0857, -0.1053, -0.5157,  0.1504, -0.1669, -0.1637,
#         -0.2270, -0.6610,  0.4720,  0.3725], device='cuda:0')
# Token: 2 diet
# tensor([-0.8759, -0.0364,  0.4084,  0.1746, -1.1774,  0.8202,  0.5426,  0.0787,
#         -0.9834, -0.6205, -0.1342, -0.1806, -0.2342, -0.1021, -0.0508,  0.3165,
#         -0.4038, -0.6639,  0.0091, -0.3535, -0.2683,  0.1252, -0.2227,  0.4642,
#         -0.9972,  0.9620, -0.1760, -1.0167, -1.0827,  0.5260,  0.3470,  0.6368,
#          0.2643, -0.9261, -0.0690,  0.8389,  0.5429,  0.6625, -0.4786, -0.7198,
#         -0.2265, -0.0621, -0.0129, -1.0039, -0.1547, -0.0473, -0.7955, -0.5197,
#         -0.3789, -0.4357,  0.0280, -0.1463, -0.3081,  0.2668, -0.0216, -0.8267,
#         -0.2990, -0.0932,  1.2136, -0.2159,  0.4026,  0.3804,  0.4553, -0.2883,
#          1.1102,  0.0804, -0.3275, -1.0472,  0.5592, -0.4503,  0.2039, -0.3907,
#          0.5257,  1.2008, -1.2997,  0.2252, -0.9950, -0.0996, -0.4593,  0.1588,
#         -0.6890, -0.1828, -0.5484,  0.3215, -0.9987, -0.2884,  0.6145, -0.2641,
#         -0.9357,  0.0824,  0.6394, -0.5965,  0.3994,  0.4925, -0.7570, -0.6092,
#         -0.0402, -1.0755,  0.9214,  0.4635], device='cuda:0')
# Token: 3 focuses
# tensor([-0.3792,  0.5214,  0.1958,  0.7115,  1.1572,  0.0984, -0.4749, -0.1631,
#          0.0222, -0.0981,  0.0779, -0.7942,  0.2926, -0.1056, -0.1628,  0.0610,
#          0.0014, -0.1441,  0.3423,  0.4088, -0.3365, -0.5738, -0.2541, -0.0980,
#         -0.1922,  0.0065, -0.0390, -0.1407, -1.2932,  0.5402, -1.0162,  0.8143,
#         -0.2315,  0.0330, -0.3977, -0.2919, -0.1068,  0.0194, -0.2370,  0.0760,
#         -0.2103, -0.0744, -0.1526,  0.5123, -0.9374, -0.3952, -0.3167,  0.2043,
#         -0.1823,  0.2356, -0.0283, -0.1983, -0.2494,  0.7678,  0.0603, -1.3513,
#          0.1350, -0.5572,  0.7603, -0.1578,  0.0558,  0.4370,  0.8573, -0.7307,
#          0.9351,  0.1647, -0.1703, -0.1142,  0.4585,  0.4703,  0.5091, -0.1359,
#         -0.2372,  0.4512, -0.0331, -0.1230,  0.1906,  0.0332, -0.5383,  0.0531,
#         -0.1309,  0.6688, -0.1901,  0.1678, -1.1717, -0.2138, -0.9356, -0.4548,
#         -0.3108, -0.1215, -0.1775,  0.1205,  0.2119,  0.1321,  0.5835,  0.4478,
#         -0.3699, -0.7105,  0.8631,  0.6647], device='cuda:0')
# Token: 4 on
# tensor([-2.1863e-01, -4.2664e-01,  5.1960e-01,  4.3103e-03,  5.8045e-01,
#         -1.0873e-01, -3.7726e-01,  4.5660e-01, -6.0627e-01, -7.5773e-02,
#          1.1306e-01,  1.7703e-01,  1.6050e-01,  7.4514e-02,  6.3649e-01,
#         -7.8852e-02,  7.5268e-01, -2.4962e-01, -5.1628e-01, -3.3348e-01,
#          6.6754e-01, -3.4183e-01,  6.1316e-01,  3.1668e-01,  6.4846e-01,
#         -7.9312e-02, -6.5219e-02, -1.7718e-01, -3.2439e-01,  5.1868e-01,
#         -2.3424e-01,  3.4381e-01,  4.6851e-02,  7.4025e-01, -4.7005e-01,
#          5.3685e-01, -3.5549e-01,  4.0737e-01, -9.3421e-02, -1.3439e-01,
#         -4.1969e-01, -3.0041e-01,  2.8646e-01,  3.7419e-01, -4.6054e-01,
#         -3.0700e-01, -3.8580e-01, -6.9317e-01, -9.2461e-04, -6.1984e-01,
#          1.1978e-01,  1.4950e-01,  1.7833e-01,  1.5313e+00, -9.2445e-01,
#         -3.0428e+00,  3.0761e-02, -6.4359e-01,  2.3824e+00,  5.6219e-01,
#         -5.6021e-01,  1.0264e+00, -4.5143e-01,  1.4117e-01,  6.5944e-01,
#          3.7572e-01,  9.8334e-02,  3.8304e-01, -7.6882e-02, -2.1781e-01,
#         -2.9892e-01, -4.9458e-01,  9.5239e-02, -6.3059e-01, -6.1311e-02,
#          1.7767e-01, -1.4051e-01,  4.7182e-01, -9.5891e-01,  4.5334e-02,
#          8.0800e-01, -2.6867e-02, -2.7483e-01,  3.5541e-01, -8.2896e-01,
#         -7.8838e-01, -7.9732e-02,  2.2941e-01, -4.5013e-01, -3.0040e-01,
#         -5.2716e-01,  1.1358e-01, -4.9906e-01,  8.2700e-01, -5.6991e-01,
#          2.5143e-01, -4.0266e-01, -2.9146e-01,  1.3816e+00,  1.8084e-01],
#        device='cuda:0')
# Token: 5 lifelong
# tensor([ 0.3703,  0.1393, -0.8225,  0.0391,  0.3182,  0.1194, -0.0202, -0.5360,
#         -0.2998,  0.0295, -1.1747, -0.2489,  0.2347, -0.3507,  0.0313, -0.8439,
#          0.5202, -0.1556, -0.0551,  0.7281, -0.5904,  0.5331, -0.5108, -0.1081,
#          0.7153,  0.2893, -0.3232, -0.6080,  0.1998,  0.0519, -0.6215,  0.8756,
#          0.3480, -0.3879, -0.3390,  0.1626,  0.1198, -0.0379,  0.4395,  0.4695,
#         -0.1313,  0.5563,  0.9929, -0.6244,  0.3531,  0.0392,  0.4932,  0.0307,
#         -0.0613, -0.0460,  0.0538, -0.8373, -0.0477, -0.1346,  1.2024, -0.9219,
#          0.9035, -0.7420,  0.5327,  0.0788,  0.6951,  0.2231, -0.5070, -0.5903,
#          0.3567,  0.1971,  0.5665, -0.3030,  0.3993, -0.1295,  0.1337,  0.3176,
#          0.1510, -0.1087, -0.4709,  0.0776, -0.0225, -0.6153, -0.8353, -0.7081,
#         -0.0913,  0.7950,  0.3591, -0.0083, -0.8287,  0.1801, -0.4578,  0.5108,
#         -1.0993, -0.3688, -0.6352, -0.0363,  0.8962,  0.5701, -0.2807, -0.6043,
#         -0.2832, -0.3556,  0.0642,  0.0545], device='cuda:0')
# Token: 6 changes
# tensor([-4.6110e-01, -1.1289e-01,  4.7149e-01,  9.6945e-02, -2.8721e-01,
#         -3.4390e-01, -4.1638e-01,  2.6481e-01, -4.4993e-01,  7.3845e-02,
#         -2.8911e-01, -3.0442e-01,  2.3623e-01, -3.1026e-01,  4.4088e-01,
#          1.4391e-01, -5.2233e-01,  1.1738e-01,  4.3027e-02, -2.5941e-02,
#         -3.6257e-01, -4.6309e-01, -4.3398e-01,  1.0739e-01, -3.3814e-01,
#         -5.1678e-01, -4.0105e-02, -7.1622e-01, -1.2042e-01, -1.5247e-01,
#          6.8916e-03,  8.0675e-01, -4.3868e-01, -5.3172e-01, -2.4406e-01,
#         -7.7843e-02,  3.1762e-01, -5.4085e-01, -9.2173e-01, -2.9376e-01,
#         -6.5687e-01, -7.0960e-01,  1.0121e-01,  1.1607e-01, -6.1711e-01,
#          5.9284e-01,  1.4807e-02,  5.1354e-03, -1.6456e-01, -9.4693e-01,
#          8.3559e-01,  1.9879e-03, -2.3271e-01,  9.2814e-01,  4.9891e-01,
#         -2.0637e+00,  3.1576e-01, -1.8236e-01,  1.5556e+00,  7.5139e-01,
#         -5.2618e-01,  6.0231e-01, -1.8075e-01,  1.3937e-01,  1.6563e+00,
#         -5.2336e-02, -5.8444e-01, -4.4639e-01,  5.0151e-01, -4.5426e-01,
#          1.6331e-01, -7.8091e-02, -2.5125e-01, -4.0722e-01,  4.6729e-01,
#         -6.0611e-01, -2.0904e-02,  8.7360e-02, -2.5851e-01, -3.2462e-02,
#          1.3337e-01, -1.0899e+00,  1.1883e-01, -1.4105e-01, -1.6244e+00,
#         -3.2432e-02,  3.9224e-01, -9.0635e-01, -7.1555e-01, -4.5024e-01,
#          9.1610e-03, -3.4166e-01, -8.4473e-01,  8.9739e-02, -4.4114e-01,
#         -2.9918e-03,  8.7607e-02, -4.5761e-01,  6.6754e-01,  8.5683e-02],
#        device='cuda:0')
# Token: 7 to
# tensor([-1.8970e-01,  5.0024e-02,  1.9084e-01, -4.9184e-02, -8.9737e-02,
#          2.1006e-01, -5.4952e-01,  9.8377e-02, -2.0135e-01,  3.4241e-01,
#         -9.2677e-02,  1.6100e-01, -1.3268e-01, -2.8160e-01,  1.8737e-01,
#         -4.2959e-01,  9.6039e-01,  1.3972e-01, -1.0781e+00,  4.0518e-01,
#          5.0539e-01, -5.5064e-01,  4.8440e-01,  3.8044e-01, -2.9055e-03,
#         -3.4942e-01, -9.9696e-02, -7.8368e-01,  1.0363e+00, -2.3140e-01,
#         -4.7121e-01,  5.7126e-01, -2.1454e-01,  3.5958e-01, -4.8319e-01,
#          1.0875e+00,  2.8524e-01,  1.2447e-01, -3.9248e-02, -7.6732e-02,
#         -7.6343e-01, -3.2409e-01, -5.7490e-01, -1.0893e+00, -4.1811e-01,
#          4.5120e-01,  1.2112e-01, -5.1367e-01, -1.3349e-01, -1.1378e+00,
#         -2.8768e-01,  1.6774e-01,  5.5804e-01,  1.5387e+00,  1.8859e-02,
#         -2.9721e+00, -2.4216e-01, -9.2495e-01,  2.1992e+00,  2.8234e-01,
#         -3.4780e-01,  5.1621e-01, -4.3387e-01,  3.6852e-01,  7.4573e-01,
#          7.2102e-02,  2.7931e-01,  9.2569e-01, -5.0336e-02, -8.5856e-01,
#         -1.3580e-01, -9.2551e-01, -3.3991e-01, -1.0394e+00, -6.7203e-02,
#         -2.1379e-01, -4.7690e-01,  2.1377e-01, -8.4008e-01,  5.2536e-02,
#          5.9298e-01,  2.9604e-01, -6.7644e-01,  1.3916e-01, -1.5504e+00,
#         -2.0765e-01,  7.2220e-01,  5.2056e-01, -7.6221e-02, -1.5194e-01,
#         -1.3134e-01,  5.8617e-02, -3.1869e-01, -6.1419e-01, -6.2393e-01,
#         -4.1548e-01, -3.8175e-02, -3.9804e-01,  4.7647e-01, -1.5983e-01],
#        device='cuda:0')
# Token: 8 healthier
# tensor([ 0.2680,  0.6255,  0.3464, -0.3184, -0.5347, -0.2007, -0.0051, -0.5401,
#          0.2950,  0.0509, -0.6144,  0.5436,  0.0218, -0.6386,  0.5697, -0.4581,
#         -0.3778, -0.8139,  0.3046,  0.4960, -0.1146,  0.5169, -0.1117,  0.0016,
#         -0.9162,  0.2095, -0.4631, -0.8740, -0.5877,  1.2744,  0.2905,  0.7854,
#          0.0620, -1.0091,  1.0915,  0.8881, -0.3659,  0.3805, -0.8682, -0.5914,
#         -0.0073, -0.5812, -0.3625, -0.0072, -0.5477,  0.5165, -0.2014,  0.0242,
#         -0.3486, -0.7462, -0.3582, -0.8206, -1.0600, -0.0212,  0.2724, -0.5524,
#          0.8419, -0.1558,  0.5104, -0.3542, -0.1172,  0.6416, -0.1318, -0.2177,
#          0.0045,  0.0126, -0.4042, -0.4904,  0.0148, -1.0508,  0.6007, -0.6665,
#          0.1920,  0.1414,  0.3170,  0.4180, -0.3660, -0.5577,  0.6580, -0.6333,
#         -0.5020,  0.4334, -0.4994,  1.4095, -0.5226, -0.4139,  0.2496, -0.2586,
#         -1.2170, -0.6794,  1.0215, -0.5767,  0.8279, -0.8360, -1.0425, -0.6478,
#          0.2718, -0.2346,  0.7126,  0.5367], device='cuda:0')
# Token: 9 eating
# tensor([-0.1989,  0.2342,  0.2359, -0.0656, -0.9809,  0.7566,  0.3073,  0.0687,
#          0.1771, -0.6301, -0.2373, -0.1295,  0.6101,  0.1584,  0.5041,  0.0928,
#         -0.2944, -0.3555, -0.1374,  0.1520, -0.0945,  0.7349, -0.0895, -0.7739,
#         -0.0698,  1.0293, -0.7559, -0.7043, -0.7003,  0.7825, -0.3162,  0.6323,
#          0.3810, -0.8855,  0.4309,  0.3112, -0.2805,  0.1308, -0.4512, -0.4420,
#         -0.2743, -0.1583, -0.1774, -0.7369,  0.0609,  0.3998, -0.6852, -0.0154,
#         -0.5382, -1.0233,  0.4085, -0.6267, -0.4562,  0.8704, -0.6554, -1.1899,
#          0.3057,  0.3317,  0.7560,  0.3262,  0.1071,  1.2355,  0.4162, -0.5513,
#          0.0215,  0.6321,  0.3371, -0.9016,  0.6371, -0.2698, -0.9218, -0.1464,
#          0.4572,  0.5997, -0.9469,  0.9154, -0.7915, -0.5717,  0.1021,  0.7625,
#         -0.0286, -0.2149, -0.8825,  0.9855, -0.9353, -0.7312, -0.0661, -0.0120,
#         -0.9656,  0.0315,  0.2158, -0.7777,  0.7290,  0.0019, -0.6706, -1.0797,
#          0.0453, -0.6973,  1.2853,  0.1574], device='cuda:0')
# Token: 10 ,
# tensor([-0.1077,  0.1105,  0.5981, -0.5436,  0.6740,  0.1066,  0.0389,  0.3548,
#          0.0635, -0.0942,  0.1579, -0.8166,  0.1417,  0.2194,  0.5850, -0.5216,
#          0.2278, -0.1664, -0.6823,  0.3587,  0.4257,  0.1902,  0.9196,  0.5756,
#          0.4618,  0.4236, -0.0954, -0.4275, -0.1657, -0.0568, -0.2959,  0.2604,
#         -0.2661, -0.0704, -0.2766,  0.1582,  0.6982,  0.4308,  0.2795, -0.4544,
#         -0.3380, -0.5818,  0.2236, -0.5778, -0.2686, -0.2042,  0.5639, -0.5852,
#         -0.1436, -0.6422,  0.0055, -0.3525,  0.1616,  1.1796, -0.4767, -2.7553,
#         -0.1321, -0.0477,  1.0655,  1.1034, -0.2208,  0.1867,  0.1318,  0.1512,
#          0.7131, -0.3521,  0.9135,  0.6178,  0.7099,  0.2395, -0.1457, -0.3786,
#         -0.0460, -0.4737,  0.2385,  0.2054, -0.1900,  0.3251, -1.1112, -0.3634,
#          0.9868, -0.0848, -0.5401,  0.1173, -1.0194, -0.2442,  0.1277,  0.0139,
#          0.0804, -0.3541,  0.3495, -0.7226,  0.3755,  0.4441, -0.9906,  0.6121,
#         -0.3511, -0.8316,  0.4529,  0.0826], device='cuda:0')
# Token: 11 rather
# tensor([-3.5491e-01,  4.3667e-01,  6.2431e-02,  4.1225e-03,  1.5369e-01,
#          5.5908e-01, -4.2255e-01,  2.5711e-02,  1.9887e-01,  8.5066e-03,
#         -2.7739e-01, -8.2044e-02,  3.8918e-01, -1.7357e-01,  4.2133e-02,
#         -6.9151e-01, -2.1619e-01,  2.7285e-01,  2.8555e-02,  5.8382e-02,
#          2.7338e-01, -7.2608e-02, -2.0035e-02, -6.1682e-01,  5.4099e-02,
#          7.4992e-02, -4.6544e-01, -4.8752e-01,  7.0664e-03,  2.7039e-02,
#         -1.2206e-02,  4.9449e-01, -6.4912e-01, -8.0488e-01,  3.8654e-01,
#          3.8591e-01,  1.1321e-01, -3.2819e-01, -2.5888e-01, -3.2106e-01,
#         -6.3034e-02, -1.2529e-01, -1.5947e-03, -4.6482e-02, -4.8865e-01,
#         -3.7804e-01,  4.2182e-01,  2.3712e-01, -4.5036e-01, -1.0447e+00,
#          4.0668e-01, -1.3395e-01,  1.3450e-01,  1.4805e+00,  9.1110e-02,
#         -2.1734e+00,  2.5354e-01, -3.7855e-01,  1.5624e+00,  1.2754e-01,
#         -1.1148e-01,  6.9392e-01, -1.8888e-01, -1.0759e-01,  9.5091e-01,
#         -1.7636e-01,  3.9376e-01,  4.8680e-02,  1.2023e-01, -2.8609e-01,
#         -3.5451e-01, -3.4718e-01,  1.2394e-01, -3.5115e-01,  1.2680e-01,
#         -1.2366e-01, -2.4838e-01,  7.4090e-02, -2.9412e-01, -1.7592e-02,
#          1.4968e-01,  1.7196e-01, -6.7871e-01, -2.0729e-04, -1.5899e+00,
#         -6.6454e-02, -5.2051e-02, -8.1836e-02, -5.2315e-02, -4.1646e-01,
#         -2.6266e-01, -2.2099e-01, -2.8210e-03, -1.0914e-01, -1.2908e-01,
#         -2.5681e-01, -2.7590e-01, -5.4545e-01,  6.2972e-01,  6.2059e-02],
#        device='cuda:0')
# Token: 12 than
# tensor([ 0.1031,  1.2472,  0.5672, -0.1912, -0.3363,  0.4345,  0.1314,  0.1086,
#         -0.3036,  0.2715,  0.2814, -0.0700,  0.1307, -0.5575,  0.6537, -0.7359,
#         -0.2884,  0.0255,  0.0451,  0.8199,  1.1737, -0.0235,  0.0459,  0.0812,
#          0.2369, -0.4301, -0.1538, -0.6308, -0.0110, -0.4923,  0.4020,  0.2192,
#          0.0601, -0.4783,  0.2234,  0.6125, -0.1794,  0.4219, -0.4755,  0.2310,
#         -0.4293, -0.6704,  0.1322, -0.1082, -0.2324, -0.1376,  0.6001, -1.0089,
#         -0.2398, -0.7942,  0.2090, -0.6083, -0.0591,  1.5629, -0.2426, -2.4183,
#         -0.0901, -0.3913,  2.0140,  0.6269,  0.2073,  1.1370, -0.2814,  0.0673,
#          0.4094, -0.0800,  0.6690,  0.5901,  0.8093, -0.3262, -0.1034, -0.4471,
#         -0.2096,  0.2248,  0.0365, -0.1226,  0.0210, -0.0995, -0.8866, -0.0974,
#          0.8984,  0.1268, -0.7042,  0.2916, -1.4439,  0.3571,  0.4829, -0.0441,
#         -0.0218, -0.4715,  0.5092,  0.1120, -0.1763, -0.5091, -0.9412, -0.0537,
#         -0.5705, -0.2584,  0.8165,  0.0898], device='cuda:0')
# Token: 13 being
# tensor([-0.0667,  0.1631,  0.3910, -0.4364,  0.2059,  0.5614,  0.1402,  0.2810,
#          0.0068, -0.0578,  0.2274,  0.2445,  1.0082,  0.0520,  0.3448, -0.7716,
#          0.4288,  0.0443, -0.7309,  0.1070,  0.3736,  0.1598,  0.5825,  0.0316,
#          0.1512, -0.1179, -0.1214, -0.2465, -0.1134,  0.6328,  0.2931,  0.3993,
#         -0.2312,  0.4173,  0.7836,  0.0683, -0.4813,  0.3034, -0.3757, -0.0400,
#         -0.5581, -0.2939,  0.4167, -0.0614,  0.6569,  0.2919,  0.4998,  0.1070,
#          0.1614, -0.8466, -0.0653, -0.2976,  0.4665,  1.4990, -0.7002, -2.1676,
#         -0.2614, -0.1202,  1.5073,  0.4845,  0.0331,  0.8327, -0.9216,  0.3025,
#          0.9585, -0.4233,  0.5827,  0.2361,  0.0893,  0.1015, -0.1459, -0.4771,
#         -0.0930,  0.1445, -0.0900, -0.1429,  0.1608,  0.1436, -1.0624,  0.1155,
#          0.2120, -0.1200, -0.6597,  0.1718, -2.1704, -0.4646,  0.0483, -0.2218,
#         -0.6507, -0.9588, -0.7331, -0.5866, -0.1088,  0.2731, -0.3279,  0.0711,
#         -0.2312, -0.0751,  0.5213, -0.1822], device='cuda:0')
# Token: 14 a
# tensor([-0.2709,  0.0440, -0.0203, -0.1740,  0.6444,  0.7121,  0.3551,  0.4714,
#         -0.2964,  0.5443, -0.7229, -0.0048,  0.0406,  0.0432,  0.2973,  0.1072,
#          0.4016, -0.5366,  0.0334,  0.0674,  0.6456, -0.0855,  0.1410,  0.0945,
#          0.7495, -0.1940, -0.6874, -0.4174, -0.2281,  0.1200, -0.4900,  0.8094,
#          0.0451, -0.1190,  0.2016,  0.3928, -0.2012,  0.3135,  0.7530,  0.2591,
#         -0.1157, -0.0293,  0.9350, -0.3607,  0.5242,  0.2371,  0.5271,  0.2287,
#         -0.5196, -0.7935, -0.2037, -0.5019,  0.1875,  0.9428, -0.4483, -3.6792,
#          0.0442, -0.2675,  2.1997,  0.2410, -0.0334,  0.6955, -0.6447, -0.0072,
#          0.8957,  0.2001,  0.4649,  0.6193, -0.1066,  0.0869, -0.4623,  0.1826,
#         -0.1585,  0.0208,  0.1937,  0.0634, -0.3167, -0.4818, -1.3848,  0.1367,
#          0.9686,  0.0500, -0.2738, -0.0357, -1.0577, -0.2447,  0.9037, -0.1244,
#          0.0808, -0.8340,  0.5720,  0.0889, -0.4253, -0.0183, -0.0800, -0.2858,
#         -0.0109, -0.4923,  0.6369,  0.2364], device='cuda:0')
# Token: 15 fad
# tensor([-0.3202,  0.0337,  0.5477, -0.4591, -0.5170,  0.2403,  0.4342, -0.1232,
#          0.6398,  0.0276,  0.0632,  0.0580,  0.1546, -0.4280,  0.4583,  0.6107,
#          0.2091,  0.1691,  0.6644, -0.1352,  0.5224,  0.1476, -0.0132, -0.0695,
#          0.0475,  0.8228,  0.5329, -0.4525, -0.6292, -0.2632, -0.1442,  0.3902,
#          0.1826, -0.5872, -0.4795,  0.1971, -0.3379, -0.1694, -0.3066, -0.7146,
#         -0.3920,  0.9490, -0.2902, -0.4002,  0.1242, -0.0867,  0.3811,  0.5863,
#          0.0084, -0.5340, -0.3141, -0.0629, -0.9964, -0.2093,  0.1507, -0.3872,
#         -0.5589,  0.6329,  0.2395, -0.4541,  0.2012,  0.4630,  0.3855,  0.2716,
#         -0.0966,  0.2434,  0.0410, -1.1370,  0.2631, -0.2040,  0.0066, -0.8214,
#         -0.2856,  0.6561, -1.1455,  0.1841, -0.4381, -0.2548, -0.1076, -0.4876,
#         -0.4399, -0.6679,  0.3210, -0.5177, -0.2837,  0.2534,  0.1718, -1.0748,
#         -0.8776, -0.5177,  0.0894,  0.4025, -0.1481, -0.1872, -0.3324, -0.7085,
#          0.3523, -1.0340, -0.0152,  0.6575], device='cuda:0')
# Token: 16 diet
# tensor([-0.8759, -0.0364,  0.4084,  0.1746, -1.1774,  0.8202,  0.5426,  0.0787,
#         -0.9834, -0.6205, -0.1342, -0.1806, -0.2342, -0.1021, -0.0508,  0.3165,
#         -0.4038, -0.6639,  0.0091, -0.3535, -0.2683,  0.1252, -0.2227,  0.4642,
#         -0.9972,  0.9620, -0.1760, -1.0167, -1.0827,  0.5260,  0.3470,  0.6368,
#          0.2643, -0.9261, -0.0690,  0.8389,  0.5429,  0.6625, -0.4786, -0.7198,
#         -0.2265, -0.0621, -0.0129, -1.0039, -0.1547, -0.0473, -0.7955, -0.5197,
#         -0.3789, -0.4357,  0.0280, -0.1463, -0.3081,  0.2668, -0.0216, -0.8267,
#         -0.2990, -0.0932,  1.2136, -0.2159,  0.4026,  0.3804,  0.4553, -0.2883,
#          1.1102,  0.0804, -0.3275, -1.0472,  0.5592, -0.4503,  0.2039, -0.3907,
#          0.5257,  1.2008, -1.2997,  0.2252, -0.9950, -0.0996, -0.4593,  0.1588,
#         -0.6890, -0.1828, -0.5484,  0.3215, -0.9987, -0.2884,  0.6145, -0.2641,
#         -0.9357,  0.0824,  0.6394, -0.5965,  0.3994,  0.4925, -0.7570, -0.6092,
#         -0.0402, -1.0755,  0.9214,  0.4635], device='cuda:0')
# Token: 17 .
# tensor([-0.3398,  0.2094,  0.4635, -0.6479, -0.3838,  0.0380,  0.1713,  0.1598,
#          0.4662, -0.0192,  0.4148, -0.3435,  0.2687,  0.0446,  0.4213, -0.4103,
#          0.1546,  0.0222, -0.6465,  0.2526,  0.0431, -0.1945,  0.4652,  0.4565,
#          0.6859,  0.0913,  0.2188, -0.7035,  0.1679, -0.3508, -0.1263,  0.6638,
#         -0.2582,  0.0365, -0.1361,  0.4025,  0.1429,  0.3813, -0.1228, -0.4589,
#         -0.2528, -0.3043, -0.1121, -0.2618, -0.2248, -0.4455,  0.2991, -0.8561,
#         -0.1450, -0.4909,  0.0083, -0.1749,  0.2752,  1.4401, -0.2124, -2.8435,
#         -0.2796, -0.4572,  1.6386,  0.7881, -0.5526,  0.6500,  0.0864,  0.3901,
#          1.0632, -0.3538,  0.4833,  0.3460,  0.8417,  0.0987, -0.2421, -0.2705,
#          0.0453, -0.4015,  0.1139,  0.0062,  0.0367,  0.0185, -1.0213, -0.2081,
#          0.6407, -0.0688, -0.5864,  0.3348, -1.1432, -0.1148, -0.2509, -0.4591,
#         -0.0968, -0.1795, -0.0634, -0.6741, -0.0689,  0.5360, -0.8777,  0.3180,
#         -0.3924, -0.2339,  0.4730, -0.0288], device='cuda:0')
# Token: 18 It
# tensor([-3.0664e-01,  1.6821e-01,  9.8511e-01, -3.3606e-01, -2.4160e-01,
#          1.6186e-01, -5.3496e-02,  4.3010e-01,  5.7342e-01, -7.1569e-02,
#          3.6101e-01,  2.6729e-01,  2.7789e-01, -7.2268e-02,  1.3838e-01,
#         -2.6714e-01,  1.2999e-01,  2.2949e-01, -1.8311e-01,  5.0163e-01,
#          4.4921e-01, -2.0821e-02,  4.2642e-01, -6.8762e-02,  4.0337e-01,
#          9.5198e-02, -3.1944e-01, -5.4651e-01, -1.3345e-01, -5.6511e-01,
#         -2.0975e-01,  1.1592e+00, -1.9400e-01,  1.9828e-01, -1.1924e-01,
#          4.1781e-01,  6.8383e-03, -2.0537e-01, -5.3375e-01, -5.2225e-01,
#         -3.8227e-01, -6.5833e-03,  1.4265e-01, -4.2502e-01, -3.1150e-01,
#          2.7352e-03,  7.5093e-01, -4.8218e-01, -1.8595e-01, -7.7104e-01,
#         -4.6406e-02, -6.9140e-02,  4.1688e-01,  1.3235e+00, -8.1742e-01,
#         -3.3998e+00, -1.1307e-01, -3.4123e-01,  2.0775e+00,  6.1369e-01,
#          1.4792e-01,  9.3753e-01, -1.0138e-01,  2.8426e-01,  9.7899e-01,
#         -3.2335e-01,  6.3697e-01,  5.8308e-01,  2.2820e-01, -3.1696e-01,
#          2.1061e-01, -6.5060e-01,  2.1653e-01, -2.4347e-01,  5.5519e-01,
#         -3.4351e-01, -9.5093e-02, -1.4715e-01, -1.2876e+00,  3.9310e-01,
#          3.0163e-01, -2.1767e-01, -1.1146e+00,  5.1349e-01, -1.3410e+00,
#         -3.0381e-01,  3.2499e-01, -4.5236e-01, -1.7743e-01, -4.8504e-02,
#         -1.2178e-01, -4.2108e-01, -4.0327e-01,  3.8452e-02, -3.6084e-01,
#          3.7738e-02, -2.1885e-01, -3.8775e-01,  3.6916e-01,  5.4521e-01],
#        device='cuda:0')
# Token: 19 emphasizes
# tensor([-2.5979e-01,  4.5997e-01,  2.7174e-02,  8.0937e-01,  4.4349e-01,
#          2.2944e-01, -5.3004e-01, -2.3243e-01,  1.0622e-01,  3.9899e-01,
#         -4.2970e-01, -4.0960e-01,  1.5999e-01, -1.0133e-02,  1.8611e-02,
#          1.9878e-01,  1.0432e-01, -1.1591e-01, -5.5751e-02,  2.5066e-01,
#         -3.9867e-01, -3.6830e-01, -3.9155e-01, -1.9921e-01, -1.6588e-01,
#          3.6337e-01, -5.6294e-01, -2.7064e-01, -1.1259e+00,  1.9591e-02,
#         -9.9169e-01,  8.8576e-01, -5.1188e-01,  2.7392e-02, -4.1537e-02,
#         -1.6167e-01, -2.3577e-04,  1.8636e-01, -4.1204e-01, -5.1872e-02,
#         -2.1567e-01,  2.9459e-01,  2.1090e-01,  4.1101e-01, -1.1518e+00,
#         -3.9802e-01,  9.9246e-02, -4.8125e-02, -2.0373e-02, -8.3827e-02,
#          1.6915e-01, -3.7528e-01, -3.4665e-01,  5.6933e-01, -1.2178e-01,
#         -6.0531e-01,  8.1475e-01, -4.6377e-01,  2.1151e-01, -1.2679e-01,
#          3.2287e-01, -3.9666e-01,  5.4188e-01, -2.0529e-01,  2.4781e-01,
#          7.4624e-02,  2.1816e-02, -4.0270e-01,  2.2306e-01,  2.1612e-01,
#          5.9466e-01, -7.4089e-02,  3.3861e-02, -4.1208e-02,  2.9906e-01,
#          9.9032e-02, -5.1589e-02, -1.7421e-01, -2.3420e-01, -2.4798e-01,
#         -5.4842e-01, -7.2362e-03, -5.6115e-01,  6.2511e-02, -7.8177e-01,
#          6.9166e-02, -4.8130e-01, -4.1047e-01, -1.4881e-01, -1.8531e-01,
#         -6.6912e-02, -2.4179e-01, -1.8682e-02,  1.2137e-01,  1.3305e-01,
#         -2.9587e-01, -4.9828e-01, -1.0902e+00,  2.0150e-01,  1.1712e+00],
#        device='cuda:0')
# Token: 20 plant-based
# tensor([-1.9410e-02,  9.7957e-02,  3.0716e-01,  3.5997e-01,  1.7439e-01,
#          2.3440e-01,  4.7278e-01,  1.8040e-02,  2.2860e-01,  2.1682e-01,
#         -7.5665e-01, -2.5974e-01,  1.7232e-01, -4.1064e-01,  3.2779e-01,
#          3.3645e-01, -5.6893e-02,  4.3998e-02,  5.0119e-01, -3.4183e-01,
#         -3.1449e-01, -4.1117e-02,  2.6993e-01,  9.6647e-02, -6.2864e-01,
#          3.1491e-01,  6.0823e-02,  3.7830e-01, -9.9656e-01,  3.5635e-01,
#          2.8172e-01, -3.4502e-01, -5.1813e-01, -1.0024e+00,  4.4009e-02,
#          3.6017e-01, -5.5842e-01,  3.6915e-01, -1.0408e-01, -2.0455e-01,
#         -1.5291e-02,  6.5360e-01, -2.3979e-01,  3.1945e-01, -5.8328e-02,
#         -3.8704e-02, -6.3550e-01,  2.6130e-01, -1.1546e-01,  1.9242e-01,
#          2.7740e-01,  1.6079e-01, -1.6264e-01, -2.8607e-01,  2.7901e-01,
#          8.5022e-01,  4.5531e-01,  3.8759e-01,  6.3339e-04, -6.6461e-01,
#          2.0884e-01, -4.0364e-01, -2.9475e-02,  2.5191e-01,  5.6294e-01,
#         -1.3702e-01, -8.2168e-02, -5.6541e-01,  3.3861e-02, -8.4236e-01,
#         -2.2100e-01, -1.5985e-01,  3.6976e-02,  1.1408e+00, -6.1609e-01,
#          8.0222e-02, -7.8150e-01, -9.7429e-02,  3.4301e-01,  1.8507e-01,
#         -9.7858e-01,  2.2490e-01, -3.5872e-01,  4.5696e-01,  3.3507e-01,
#          4.4455e-01,  4.3770e-01,  9.8863e-02, -4.4314e-01, -2.5095e-01,
#          5.6373e-01, -5.0892e-01,  5.1766e-01, -4.0886e-02, -2.3153e-01,
#         -6.4497e-01,  4.3637e-03, -7.7186e-02,  3.8713e-01,  1.7100e-01],
#        device='cuda:0')
# Token: 21 eating
# tensor([-0.1989,  0.2342,  0.2359, -0.0656, -0.9809,  0.7566,  0.3073,  0.0687,
#          0.1771, -0.6301, -0.2373, -0.1295,  0.6101,  0.1584,  0.5041,  0.0928,
#         -0.2944, -0.3555, -0.1374,  0.1520, -0.0945,  0.7349, -0.0895, -0.7739,
#         -0.0698,  1.0293, -0.7559, -0.7043, -0.7003,  0.7825, -0.3162,  0.6323,
#          0.3810, -0.8855,  0.4309,  0.3112, -0.2805,  0.1308, -0.4512, -0.4420,
#         -0.2743, -0.1583, -0.1774, -0.7369,  0.0609,  0.3998, -0.6852, -0.0154,
#         -0.5382, -1.0233,  0.4085, -0.6267, -0.4562,  0.8704, -0.6554, -1.1899,
#          0.3057,  0.3317,  0.7560,  0.3262,  0.1071,  1.2355,  0.4162, -0.5513,
#          0.0215,  0.6321,  0.3371, -0.9016,  0.6371, -0.2698, -0.9218, -0.1464,
#          0.4572,  0.5997, -0.9469,  0.9154, -0.7915, -0.5717,  0.1021,  0.7625,
#         -0.0286, -0.2149, -0.8825,  0.9855, -0.9353, -0.7312, -0.0661, -0.0120,
#         -0.9656,  0.0315,  0.2158, -0.7777,  0.7290,  0.0019, -0.6706, -1.0797,
#          0.0453, -0.6973,  1.2853,  0.1574], device='cuda:0')
# Token: 22 ,
# tensor([-0.1077,  0.1105,  0.5981, -0.5436,  0.6740,  0.1066,  0.0389,  0.3548,
#          0.0635, -0.0942,  0.1579, -0.8166,  0.1417,  0.2194,  0.5850, -0.5216,
#          0.2278, -0.1664, -0.6823,  0.3587,  0.4257,  0.1902,  0.9196,  0.5756,
#          0.4618,  0.4236, -0.0954, -0.4275, -0.1657, -0.0568, -0.2959,  0.2604,
#         -0.2661, -0.0704, -0.2766,  0.1582,  0.6982,  0.4308,  0.2795, -0.4544,
#         -0.3380, -0.5818,  0.2236, -0.5778, -0.2686, -0.2042,  0.5639, -0.5852,
#         -0.1436, -0.6422,  0.0055, -0.3525,  0.1616,  1.1796, -0.4767, -2.7553,
#         -0.1321, -0.0477,  1.0655,  1.1034, -0.2208,  0.1867,  0.1318,  0.1512,
#          0.7131, -0.3521,  0.9135,  0.6178,  0.7099,  0.2395, -0.1457, -0.3786,
#         -0.0460, -0.4737,  0.2385,  0.2054, -0.1900,  0.3251, -1.1112, -0.3634,
#          0.9868, -0.0848, -0.5401,  0.1173, -1.0194, -0.2442,  0.1277,  0.0139,
#          0.0804, -0.3541,  0.3495, -0.7226,  0.3755,  0.4441, -0.9906,  0.6121,
#         -0.3511, -0.8316,  0.4529,  0.0826], device='cuda:0')
# Token: 23 which
# tensor([ 3.0240e-02,  4.4606e-01,  4.3166e-01, -3.7528e-01,  2.9068e-01,
#          2.3032e-01,  1.8125e-01,  4.0201e-01,  1.3518e-01, -1.9562e-01,
#          3.0639e-01, -1.3239e-01,  6.7897e-01,  4.2234e-01,  3.2637e-01,
#         -1.5281e-01,  3.7698e-01, -2.3303e-01, -3.3817e-01,  3.0588e-01,
#          4.4918e-01, -8.3624e-01,  5.9146e-01,  2.4958e-01,  3.9986e-01,
#         -5.0172e-01, -2.3544e-01, -1.4696e-01, -3.5144e-01, -5.6852e-01,
#          8.9540e-02,  8.2612e-01, -2.6586e-01,  3.9030e-01, -3.6849e-02,
#          4.8257e-01,  7.1664e-01,  1.1004e-01, -5.9354e-01, -3.3216e-01,
#         -2.5736e-01, -3.4531e-01, -2.6326e-02, -2.3747e-01,  1.9656e-04,
#         -2.7480e-01,  3.8512e-01, -3.9581e-01,  1.1404e-01, -2.5174e-01,
#         -3.2470e-01,  8.9608e-02,  2.4929e-01,  1.5127e+00, -1.9762e-01,
#         -2.8509e+00, -5.3833e-01, -4.7111e-01,  1.7859e+00,  7.8126e-01,
#         -1.2963e-01,  5.6077e-01,  3.2151e-01,  3.5571e-01,  8.4547e-01,
#          1.4931e-01,  1.1487e-01,  3.0625e-01,  5.4774e-01, -5.0426e-01,
#          3.3824e-01, -6.2043e-01, -1.2869e-02,  6.6666e-02,  6.2731e-02,
#         -4.4534e-01,  1.5541e-01,  2.1801e-01, -1.7320e+00,  4.2054e-01,
#          3.6319e-01, -7.2258e-02, -7.4811e-01,  1.9888e-01, -1.4461e+00,
#         -2.7576e-01,  2.6646e-01, -5.7838e-01,  5.6151e-01, -2.8701e-02,
#         -2.4660e-01, -4.2500e-01, -5.7154e-01,  3.1939e-01, -2.2075e-01,
#          4.6528e-01, -1.6606e-01, -7.9923e-01,  8.0849e-01,  3.7378e-01],
#        device='cuda:0')
# Token: 24 does
# tensor([-0.0934,  0.5560,  0.7485, -0.6806, -0.3242,  0.0402, -0.5229,  0.1786,
#          0.5823, -0.1467, -0.1670, -0.0784,  0.1960,  0.2287, -0.3538,  0.1470,
#          0.1468,  0.5704, -0.0838,  0.8971, -0.1413, -0.3055, -0.1653, -0.2769,
#          0.0181,  0.3845, -0.4703, -1.2409,  0.1501, -0.5137, -0.0539,  1.3106,
#         -0.1716,  0.0471,  0.1124,  0.7067,  0.1251, -0.0910, -0.0126, -0.3005,
#         -0.2922,  0.2033, -0.0412, -0.5051, -0.7371, -0.3266,  0.2266, -0.5762,
#         -0.3255, -1.0971,  0.5318, -0.1669,  0.1484,  0.9746,  0.1679, -2.5665,
#          0.0778, -0.2381,  1.5805,  0.4072,  0.0358,  0.4684,  0.0237, -0.2713,
#          1.1255,  0.3988,  0.7415,  0.3514, -0.2643, -0.1957,  0.1862, -0.7813,
#          0.0401, -0.3625,  0.6734, -0.3597, -0.1184, -0.3330, -0.6525,  0.1629,
#          0.3205, -0.5426, -0.7646, -0.0514, -1.5171, -0.1772,  0.1022, -0.1044,
#          0.4055, -0.1394,  0.0200, -0.1697, -0.0468, -0.2840, -0.2174,  0.2320,
#         -0.0923, -0.6857,  0.2088,  0.5903], device='cuda:0')
# Token: 25 show
# tensor([ 1.0735e-01, -1.3863e-01,  5.7066e-02, -6.1203e-01, -9.6671e-02,
#         -2.6425e-01,  6.2813e-02,  9.5611e-01, -2.6705e-01, -4.2122e-01,
#         -2.5975e-01, -3.3355e-01,  2.8623e-01, -2.0724e-01,  1.6318e-01,
#          3.1586e-01,  6.1206e-01,  2.8672e-01, -1.0276e-01,  6.4146e-01,
#          3.8259e-01, -7.1012e-01, -3.7712e-02, -4.9555e-01,  7.1959e-01,
#         -2.8056e-01,  6.7913e-01, -7.6652e-02,  4.2956e-01, -1.7922e-01,
#         -8.5417e-02,  4.3329e-01,  2.2443e-01,  8.0722e-01,  7.1308e-02,
#          6.3508e-01,  1.8468e-01, -2.1150e-01, -5.8941e-01, -2.9348e-01,
#         -5.3272e-02, -1.2164e-04, -6.7823e-01,  7.6149e-01, -4.5133e-01,
#         -4.0854e-01, -3.1185e-01, -6.9396e-01,  2.5989e-01, -1.1493e+00,
#         -4.6673e-01, -2.2150e-01,  5.7337e-01,  8.6139e-01, -2.6505e-02,
#         -2.8989e+00, -4.6397e-01,  2.7566e-03,  1.0905e+00,  5.7473e-01,
#         -7.6244e-02,  1.2370e+00, -3.7543e-01, -2.8546e-01,  1.1007e+00,
#          1.3005e-01,  4.0481e-01, -2.2947e-02, -6.3125e-02,  3.7890e-01,
#          2.7186e-01, -4.3610e-02, -5.1219e-01,  1.4266e-01,  2.0057e-01,
#          2.0669e-01,  3.2724e-01,  7.3422e-02, -6.8120e-01, -1.9239e-03,
#         -6.9590e-02, -9.1188e-02,  8.7003e-02, -3.4550e-01, -1.7040e+00,
#         -8.8712e-01, -3.4478e-01,  6.2312e-01, -2.8113e-01, -2.2109e-01,
#          4.9630e-02,  1.1402e-02,  3.9442e-01,  5.9711e-04, -4.2634e-01,
#         -4.0172e-01, -4.3702e-01, -5.1945e-01,  8.8829e-01,  5.4760e-01],
#        device='cuda:0')
# Token: 26 positive
# tensor([ 0.4338,  0.3966, -0.0821,  0.2492, -0.1481, -0.5375, -0.1760, -0.0851,
#         -0.4078, -0.4445, -0.5845, -0.1497,  0.3356, -0.2803,  0.5989,  0.8954,
#         -0.5924, -0.1646,  0.3466,  0.2794,  0.7617, -0.2685, -0.9759,  0.4147,
#         -1.0014,  0.0632,  0.9539,  0.1707, -0.1410,  0.6985,  0.0821,  0.5214,
#         -0.2746,  0.5642,  0.8728, -0.2306,  0.1220,  0.4895, -1.2710,  0.0896,
#         -0.8464, -0.2613,  0.2516, -0.5274,  0.1356,  0.1231,  0.0525, -0.4133,
#         -0.2562, -1.3112,  0.9158, -0.1956,  0.0530,  0.5037, -0.1595, -2.3884,
#         -0.1212,  0.2646,  1.3294, -0.4529, -0.1041,  0.3930, -1.0804,  0.1438,
#          0.5202,  0.5754,  0.3678, -0.0372,  0.2394, -0.2735,  0.2400,  0.2892,
#         -0.0817, -0.0824,  0.6115,  0.6513, -0.1529, -0.6315, -0.6720, -1.0458,
#          0.0804,  0.2621, -1.0728,  0.0677, -1.0979, -0.1532,  0.2471,  0.0085,
#         -0.9112, -0.7585, -0.9431,  0.0076, -0.4624, -0.0751,  0.2546,  0.7108,
#         -0.5818, -0.3248, -0.1583,  0.6779], device='cuda:0')
# Token: 27 benefits
# tensor([ 2.5558e-01,  1.0563e+00,  8.8470e-04,  4.4118e-01,  7.8414e-02,
#         -9.0805e-01, -2.7658e-01,  1.6083e-01, -3.8882e-03, -6.4772e-01,
#         -4.1708e-01,  3.2736e-01,  6.7881e-02, -7.2620e-03,  6.0495e-01,
#         -1.0737e+00,  5.4571e-01,  2.2426e-01, -1.0119e-01,  3.3821e-01,
#         -2.1741e-01, -4.8820e-02, -6.0286e-01,  7.5166e-01, -5.6593e-01,
#         -3.1033e-01, -4.2297e-01, -1.2260e+00, -9.6986e-01, -8.9933e-01,
#          4.9306e-01,  8.9651e-01, -5.3292e-02, -5.9063e-01,  3.1048e-02,
#          2.8700e-02,  7.2520e-02,  5.1797e-01, -1.1715e+00, -1.6148e-01,
#         -1.2426e-01, -3.8101e-01,  1.5462e-01,  2.1870e-01,  1.1858e-01,
#         -3.1436e-01,  9.3558e-02, -1.4982e-02, -3.8261e-01, -7.3426e-01,
#          1.3903e-01, -3.8730e-01, -5.7285e-01,  9.4023e-01,  3.0671e-01,
#         -9.3982e-01,  1.0940e+00, -1.1180e+00,  1.8842e+00, -6.7366e-02,
#          3.1215e-01, -5.6708e-02, -1.9844e-01, -7.1306e-01,  4.7693e-01,
#         -8.1109e-02,  8.1374e-02, -2.8454e-01,  8.5128e-01, -4.0982e-01,
#          1.5200e-01, -4.4776e-02, -4.2278e-01,  2.4529e-01,  3.3094e-01,
#          1.4972e-01,  8.3067e-02, -5.4624e-01, -6.0628e-01, -6.3902e-02,
#          4.7442e-01, -8.1686e-03,  5.1143e-01, -7.5576e-01, -2.0738e+00,
#         -1.2929e-01,  4.1600e-01,  1.5515e-01, -8.6338e-01, -5.4374e-01,
#         -3.3037e-01, -6.0074e-01,  1.0109e-01, -5.7665e-01, -4.4641e-01,
#         -6.5783e-02,  6.8821e-01,  2.1443e-01,  9.9843e-01,  9.6123e-02],
#        device='cuda:0')
# Token: 28 to
# tensor([-1.8970e-01,  5.0024e-02,  1.9084e-01, -4.9184e-02, -8.9737e-02,
#          2.1006e-01, -5.4952e-01,  9.8377e-02, -2.0135e-01,  3.4241e-01,
#         -9.2677e-02,  1.6100e-01, -1.3268e-01, -2.8160e-01,  1.8737e-01,
#         -4.2959e-01,  9.6039e-01,  1.3972e-01, -1.0781e+00,  4.0518e-01,
#          5.0539e-01, -5.5064e-01,  4.8440e-01,  3.8044e-01, -2.9055e-03,
#         -3.4942e-01, -9.9696e-02, -7.8368e-01,  1.0363e+00, -2.3140e-01,
#         -4.7121e-01,  5.7126e-01, -2.1454e-01,  3.5958e-01, -4.8319e-01,
#          1.0875e+00,  2.8524e-01,  1.2447e-01, -3.9248e-02, -7.6732e-02,
#         -7.6343e-01, -3.2409e-01, -5.7490e-01, -1.0893e+00, -4.1811e-01,
#          4.5120e-01,  1.2112e-01, -5.1367e-01, -1.3349e-01, -1.1378e+00,
#         -2.8768e-01,  1.6774e-01,  5.5804e-01,  1.5387e+00,  1.8859e-02,
#         -2.9721e+00, -2.4216e-01, -9.2495e-01,  2.1992e+00,  2.8234e-01,
#         -3.4780e-01,  5.1621e-01, -4.3387e-01,  3.6852e-01,  7.4573e-01,
#          7.2102e-02,  2.7931e-01,  9.2569e-01, -5.0336e-02, -8.5856e-01,
#         -1.3580e-01, -9.2551e-01, -3.3991e-01, -1.0394e+00, -6.7203e-02,
#         -2.1379e-01, -4.7690e-01,  2.1377e-01, -8.4008e-01,  5.2536e-02,
#          5.9298e-01,  2.9604e-01, -6.7644e-01,  1.3916e-01, -1.5504e+00,
#         -2.0765e-01,  7.2220e-01,  5.2056e-01, -7.6221e-02, -1.5194e-01,
#         -1.3134e-01,  5.8617e-02, -3.1869e-01, -6.1419e-01, -6.2393e-01,
#         -4.1548e-01, -3.8175e-02, -3.9804e-01,  4.7647e-01, -1.5983e-01],
#        device='cuda:0')
# Token: 29 overall
# tensor([ 1.2184e-01, -5.8856e-02,  8.7792e-01,  2.1520e-01,  1.1825e-01,
#         -1.1499e+00,  2.5973e-01, -1.2486e-01, -7.5207e-01,  3.4651e-01,
#          1.5069e-01, -1.8766e-02,  1.0867e-01, -1.0153e+00, -2.6263e-01,
#          3.1994e-01, -3.4742e-01, -3.5419e-01, -6.6321e-02, -1.2669e-02,
#          2.5068e-01, -1.7526e-01,  7.7030e-02,  6.3252e-01, -6.6633e-02,
#         -5.5134e-01,  5.9247e-01, -4.5003e-01, -5.3883e-02, -6.0775e-01,
#         -4.7454e-01,  1.3024e-01,  5.6481e-02, -4.1660e-02, -7.8600e-02,
#          1.4263e-03,  1.3890e-01,  1.1344e+00, -3.4919e-01,  8.2678e-01,
#          7.7036e-01, -7.9902e-01,  5.4780e-01,  5.5713e-01,  1.3242e-01,
#         -8.6448e-02,  5.0290e-01, -6.7434e-01, -3.6007e-01, -1.5875e+00,
#          3.1310e-01, -2.3047e-01, -7.9297e-01,  9.7315e-01, -8.9894e-02,
#         -2.5067e+00,  6.9401e-01, -8.0733e-02,  1.1936e+00,  2.0851e-01,
#         -4.0877e-01, -1.8223e-01, -3.5106e-01,  4.4411e-01,  6.6250e-01,
#          4.5118e-01, -4.3003e-01, -1.0709e-01,  5.7686e-01,  1.7025e-01,
#          4.7159e-01,  6.3644e-02, -3.5358e-01,  4.9804e-01,  6.5900e-01,
#          5.3489e-01, -8.6688e-01, -5.3481e-01, -1.1758e-01, -6.6158e-01,
#          4.3562e-03,  6.7687e-01, -7.9554e-01,  5.1560e-01, -1.1456e+00,
#         -9.0841e-01, -7.3489e-02, -6.5858e-01,  9.8904e-02,  1.3060e-01,
#         -2.6238e-01, -1.6173e-01, -1.3165e-01, -6.5547e-02, -4.6343e-01,
#         -7.6912e-02,  4.9406e-02, -3.5575e-01,  7.6198e-01, -1.4255e-01],
#        device='cuda:0')
# Token: 30 health
# tensor([-0.1326,  0.3974, -0.0281,  0.1371, -0.2710, -0.1565, -0.1656, -0.2025,
#          0.2329, -0.2521, -0.4399, -0.2634, -0.0264,  0.0773,  0.1661, -0.4870,
#          0.7852,  0.0498, -0.8040, -0.2042, -0.5481,  0.0441,  0.1629,  0.3817,
#         -1.2866,  0.5128,  0.2257, -0.9918, -1.3249,  0.1346,  0.2032,  0.4589,
#         -0.0110,  0.3275, -0.8688,  0.4113, -0.7529,  0.9439, -0.8130,  0.4457,
#         -0.3097, -0.0660, -0.3172, -0.7721,  0.3825,  0.3566, -0.3224,  0.2313,
#         -0.7600, -0.5808,  0.7434, -0.4501, -0.6344,  0.7851,  0.4874, -1.9284,
#          0.7020, -0.1666,  1.9360,  0.3898,  0.3628, -0.1301,  0.3257, -0.6980,
#          0.5991,  0.6428, -0.2185,  0.0432,  1.2776, -0.0238,  0.0220,  0.0588,
#         -0.2809, -0.0307,  0.5035,  0.0944, -0.1817,  0.1424, -1.1326, -0.5564,
#          0.7036,  0.1970,  0.1833,  0.0907, -2.1113, -0.3190,  0.1978,  0.2987,
#         -0.7462, -0.3564,  1.1171, -0.5612,  0.0757,  0.1933, -0.9847,  0.9688,
#          0.6638, -0.5398,  0.8843, -0.5774], device='cuda:0')
# Token: 31 .
# tensor([-0.3398,  0.2094,  0.4635, -0.6479, -0.3838,  0.0380,  0.1713,  0.1598,
#          0.4662, -0.0192,  0.4148, -0.3435,  0.2687,  0.0446,  0.4213, -0.4103,
#          0.1546,  0.0222, -0.6465,  0.2526,  0.0431, -0.1945,  0.4652,  0.4565,
#          0.6859,  0.0913,  0.2188, -0.7035,  0.1679, -0.3508, -0.1263,  0.6638,
#         -0.2582,  0.0365, -0.1361,  0.4025,  0.1429,  0.3813, -0.1228, -0.4589,
#         -0.2528, -0.3043, -0.1121, -0.2618, -0.2248, -0.4455,  0.2991, -0.8561,
#         -0.1450, -0.4909,  0.0083, -0.1749,  0.2752,  1.4401, -0.2124, -2.8435,
#         -0.2796, -0.4572,  1.6386,  0.7881, -0.5526,  0.6500,  0.0864,  0.3901,
#          1.0632, -0.3538,  0.4833,  0.3460,  0.8417,  0.0987, -0.2421, -0.2705,
#          0.0453, -0.4015,  0.1139,  0.0062,  0.0367,  0.0185, -1.0213, -0.2081,
#          0.6407, -0.0688, -0.5864,  0.3348, -1.1432, -0.1148, -0.2509, -0.4591,
#         -0.0968, -0.1795, -0.0634, -0.6741, -0.0689,  0.5360, -0.8777,  0.3180,
#         -0.3924, -0.2339,  0.4730, -0.0288], device='cuda:0')
